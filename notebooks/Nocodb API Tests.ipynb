# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.database import Database

# %%
db = Database()

# %%
result, _ = db.scan("Pages", limit=10)
titles = set([record["title"] for record in result])
titles
# Out:
# {'ДАХеО/1',
#  'ДАХеО/1/1',
#  'ДАХеО/1/1/11',
#  'ДАХеО/1/1/19',
#  'ДАХеО/1/1/20',
#  'ДАХеО/1/2',
#  'ДАХеО/3',
#  'ДАХеО/4',
#  'ДАХеО/5',
#  'ДАХеО/Д'}

# %%
result, _ = db.scan("Documents", limit=200)
links = set([record["link"] for record in result])
#links

# %%
db.lookup("Pages", list(titles)[0])
# Out:
# 182

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Documents", list(links)[0])
# Out:
# 55

# %%
doc_ids = db.lookup("Documents", links)

# %%
doc_ids = db.lookup("Documents", links)

# %%
db.lookup("Pages", "foo")

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
len(db.lookup("Documents", links))
# Out:
# 100

# %%
db.read("Pages", db.lookup("Pages", 'ДАХеО/1/1/20'))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/1/1/20 ) LABEL::( ДАХеО/1/1/20 )',
#  'Id': 189,
#  'title': 'ДАХеО/1/1/20',
#  'description': 'Instructions of the Governor-General of Novorossiysk, reports of officials on clarifying the connections of the British citizen D. Melvel with the schismatics',
#  'availability': 'linked',
#  'level': 'case',
#  'comments': '(not on JRF)',
#  'label': '20',
#  'Pages_id': 185,
#  'years': '1854-1855',
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'description_uk': None,
#  'CreatedAt': '2025-09-24 20:47:09+00:00',
#  'UpdatedAt': '2025-09-25 03:01:45+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 185, 'title': 'ДАХеО/1/1'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
pages = db.read("Pages", list(db.lookup("Pages", titles).values()))
len(pages)
# Out:
# 10

# %%
docs = db.read("Documents", list(db.lookup("Documents", links).values()))
len(docs)
# Out:
# 100

# %%
db.read("Pages", [100000,])
# Out:
# [{}]

# %%
db.read("Pages", 100000)
# Out:
# {}

# %%
db.read("Pages", db.lookup("Pages", "ДАХеО/Д"))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/Д ) LABEL::( ДАХеО/Д )',
#  'Id': 180,
#  'title': 'ДАХеО/Д',
#  'description': 'State archive of Kherson region. Foundations of the pre-Soviet period',
#  'availability': 'linked',
#  'level': 'archive',
#  'comments': None,
#  'label': 'DAHEO-D',
#  'Pages_id': None,
#  'years': None,
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'description_uk': None,
#  'CreatedAt': '2025-09-24 20:40:29+00:00',
#  'UpdatedAt': '2025-09-25 03:02:38+00:00',
#  'change_date': '2025-08-21 00:00:00+00:00',
#  'reference_date': '2024-12-25 00:00:00+00:00',
#  'children': 154,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
doc=db.read("Documents", db.lookup("Documents", list(links)[0]))
doc
# Out:
# {'linked_title': 'URI::( https://uk.wikisource.org/wiki/Файл:ДАХерО_14-1-269._1794._Переписка_уездного_землемера_Пиваровича_об_вымежевании_под_церковь_земли_из_дачи_Астафьева.pdf ) LABEL::( Файл:ДАХерО_14-1-269._1794._Переписка_уездного_землемера_Пиваровича_об_вымежевании_под_церковь_земли_из_дачи_Астафьева.pdf )',
#  'Id': 55,
#  'title': 'Файл:ДАХерО_14-1-269._1794._Переписка_уездного_землемера_Пиваровича_об_вымежевании_под_церковь_земли_из_дачи_Астафьева.pdf',
#  'doc_type': ['O'],
#  'content_code': None,
#  'process_code': 'C2',
#  'processor': None,
#  'pages_processed': 0,
#  'comments': None,
#  'link': 'https://uk.wikisource.org/wiki/Файл:ДАХерО_14-1-269._1794._Переписка_уездного_землемера_Пиваровича_об_вымежевании_под_церковь_земли_из_дачи_Астафьева.pdf',
#  'Pages_id': 391,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640_0Yge5.jpg',
#    'title': '_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 210035,
#    'width': 640,
#    'height': 974,
#    'id': 'atlwtt5ve2hn1rgf',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640_0Yge5.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20260102%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20260102T205024Z&X-Amz-Expires=7778&X-Amz-Signature=8e9f840411c2c6d4a19540f36af7deec6c68f6be4304899d5087e32b87b10328&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640_0Yge5.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20260102%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20260102T205024Z&X-Amz-Expires=7778&X-Amz-Signature=275eeec715322b8cd853a237a1f128dfc0a2487ba3d317f93dd1ed7fc5dd1192&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640_0Yge5.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20260102%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20260102T205024Z&X-Amz-Expires=7778&X-Amz-Signature=24e6c0fb37243abc29daa7a7eba7b48ef5e1729b15abea942aa7883ecfd9c418&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640_0Yge5.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20260102%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20260102T205021Z&X-Amz-Expires=7779&X-Amz-Signature=1aed780996cd2e550753a861609143b418606ec1eeaadafde56e681ce701dd67&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22_______14-1-269._1794.___________________________________________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'source': None,
#  'byte_size': None,
#  'mimetype': None,
#  'mediatype': None,
#  'width': None,
#  'height': None,
#  'page_count': None,
#  'sha1_hash': None,
#  'description_url': None,
#  'thumb_width': None,
#  'thumb_height': None,
#  'thumb_url': None,
#  'CreatedAt': '2025-09-24 23:50:11+00:00',
#  'UpdatedAt': '2025-09-25 21:06:08+00:00',
#  'timestamp': None,
#  'description (from Pages)': "Correspondence of the county surveyor Pivarovich about the demarcation for the church of land from Astafyev's dacha in Novomirgorod uyezd",
#  'description_uk (from Pages)': None,
#  'owning_page': {'Id': 391, 'title': 'ДАХеО/14/1/269'}}

# %%
test_page = {'title': 'test 1', "comments": "foo"}

# %%
rid = db.write("Pages", test_page)

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'foo',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'description_uk': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2026-01-02 20:53:07+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
test_page = {'title': 'test 1', "comments": "bar"}

# %%
db.write("Pages", test_page)
# Out:
# 1544

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'bar',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'description_uk': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2026-01-02 20:53:08+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
test_pages = [{"title": f"test {i}"} for i in range(20)]
test_pages
# Out:
# [{'title': 'test 0'},
#  {'title': 'test 1'},
#  {'title': 'test 2'},
#  {'title': 'test 3'},
#  {'title': 'test 4'},
#  {'title': 'test 5'},
#  {'title': 'test 6'},
#  {'title': 'test 7'},
#  {'title': 'test 8'},
#  {'title': 'test 9'},
#  {'title': 'test 10'},
#  {'title': 'test 11'},
#  {'title': 'test 12'},
#  {'title': 'test 13'},
#  {'title': 'test 14'},
#  {'title': 'test 15'},
#  {'title': 'test 16'},
#  {'title': 'test 17'},
#  {'title': 'test 18'},
#  {'title': 'test 19'}]

# %%
rids = db.write("Pages", test_pages)

# %%
[rec["title"] for rec in db.read("Pages", rids)]
# Out:
# ['test 0',
#  'test 1',
#  'test 2',
#  'test 3',
#  'test 4',
#  'test 5',
#  'test 6',
#  'test 7',
#  'test 8',
#  'test 9',
#  'test 10',
#  'test 11',
#  'test 12',
#  'test 13',
#  'test 14',
#  'test 15',
#  'test 16',
#  'test 17',
#  'test 18',
#  'test 19']

# %%
test_docs = [{"link": f"http://test.doc/{i}", "title": f"test doc {i}", "doc_type": ["O","C","L","V"]} for i in range(10)]
test_docs
# Out:
# [{'link': 'http://test.doc/0',
#   'title': 'test doc 0',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/1',
#   'title': 'test doc 1',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/2',
#   'title': 'test doc 2',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/3',
#   'title': 'test doc 3',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/4',
#   'title': 'test doc 4',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/5',
#   'title': 'test doc 5',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/6',
#   'title': 'test doc 6',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/7',
#   'title': 'test doc 7',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/8',
#   'title': 'test doc 8',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/9',
#   'title': 'test doc 9',
#   'doc_type': ['O', 'C', 'L', 'V']}]

# %%
dids = db.write("Documents", test_docs)
dids
# Out:
# [660, 665, 667, 668, 662, 661, 669, 664, 663, 666]

# %%
db.read("Pages",rids[0])
# Out:
# {'wiki_link': '',
#  'Id': 1554,
#  'title': 'test 0',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': None,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'description_uk': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2026-01-02 20:53:10+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 6,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
db.read("Documents", dids[0])
# Out:
# {'linked_title': 'URI::( http://test.doc/0 ) LABEL::( test doc 0 )',
#  'Id': 660,
#  'title': 'test doc 0',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': None,
#  'processor': None,
#  'pages_processed': None,
#  'comments': None,
#  'link': 'http://test.doc/0',
#  'Pages_id': None,
#  'doc_image': None,
#  'birddog_alert': False,
#  'source': None,
#  'byte_size': None,
#  'mimetype': None,
#  'mediatype': None,
#  'width': None,
#  'height': None,
#  'page_count': None,
#  'sha1_hash': None,
#  'description_url': None,
#  'thumb_width': None,
#  'thumb_height': None,
#  'thumb_url': None,
#  'CreatedAt': '2026-01-02 20:53:11+00:00',
#  'UpdatedAt': None,
#  'timestamp': None,
#  'description (from Pages)': None,
#  'description_uk (from Pages)': None,
#  'owning_page': None}

# %%
db.create_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 1"),
    db.lookup("Pages", "test 0"),
)

# %%
for i in range(10):
    db.create_links(
        "Documents", "owning_page", 
        db.lookup("Documents", f"http://test.doc/{i}"),
        db.lookup("Pages", f"test {i}"),
)

# %%
db.delete_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
    db.lookup("Pages", "test 0"),
)

# %%
db.get_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
)
# Out:
# []

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    db.lookup("Pages", "test 2"),
)

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    list(db.lookup("Pages", {f"test {i}" for i in range(3,7)}).values()),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1554]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1558]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# [1545]

# %%
db.delete_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# []

# %%
#db.delete("Pages", rids)

# %%
#db.delete("Documents", dids)

# %%
page = db.read("Pages", db.lookup("Pages", "test 6"))
page
# Out:
# {'wiki_link': '',
#  'Id': 1545,
#  'title': 'test 6',
#  'description': 'description update 3',
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'description_uk': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2026-01-02 20:53:41+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
page["description"] = "description update 3"

# %%
db.write("Pages", page)
# Out:
# 1545

# %%
did = db.get_links("Pages", "doc_links", db.lookup("Pages", "test 6"))[0]

# %%
doc = db.read("Documents", did)
doc
# Out:
# {'linked_title': 'URI::( http://test.doc/6 ) LABEL::( test doc 6 )',
#  'Id': 669,
#  'title': 'test doc 6',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': None,
#  'processor': None,
#  'pages_processed': None,
#  'comments': None,
#  'link': 'http://test.doc/6',
#  'Pages_id': 1545,
#  'doc_image': None,
#  'birddog_alert': False,
#  'source': None,
#  'byte_size': None,
#  'mimetype': None,
#  'mediatype': None,
#  'width': None,
#  'height': None,
#  'page_count': None,
#  'sha1_hash': None,
#  'description_url': None,
#  'thumb_width': None,
#  'thumb_height': None,
#  'thumb_url': None,
#  'CreatedAt': '2026-01-02 20:53:11+00:00',
#  'UpdatedAt': None,
#  'timestamp': None,
#  'description (from Pages)': 'description update 3',
#  'description_uk (from Pages)': None,
#  'owning_page': {'Id': 1545, 'title': 'test 6'}}

# %%
doc["comments"] = "new doc comment"

# %%
db.write("Documents", doc)
# Out:
# 669

# %%
doc["doc_type"] = None

# %%
db.write("Documents", doc)
# Out:
# 669

# %%
#db.delete("Pages", rids)
#db.delete("Documents", dids)

# %%
#db._upload_file("test/test_image.jpg")

# %%
db.set_attachments("Documents", did, "doc_image", ["test/test_image.jpg", "test/test_image_2.jpg"])

# %%
db.read("Documents", 603)
# Out:
# {}

# %%
db.clear_attachments("Documents", did, "doc_image")

# %%
db.set_attachments("Documents", did, "doc_image", "test/test_image_2.jpg")
