# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
# uncomment to use hosted db
#del os.environ["BIRDDOG_USE_LOCAL_NOCODB"]
if os.environ.get("BIRDDOG_USE_LOCAL_NOCODB"):
    print("using local nocodb")
else:
    print("using aws nocodb")
# Out:
# using local nocodb

# %%
from birddog.database import Database
# Out:
# 2026-07-08 16:34:25,597 [INFO] Using local nocodb api: http://localhost:8080

# %%
db = Database()
# Out:
# 2026-07-08 16:34:25,749 [INFO] creating NocoDBDatabase(host=http://localhost:8080, base_id=p79fvr9cjqgpv5n) instance
# 2026-07-08 16:34:25,787 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   localhost:api                         20.00    26.69    39.00       0.00           24

# %%
records, cursor = db.scan("Documents", fields=["url", "label", "owning_pages"], limit=3)

# %%
len(records)

# %%
records

# %%
cursor

# %%
rec_v3, cursor = db.scan("Documents", fields=["url", "label", "owning_pages"], limit=3, use_v3=True, cursor="2")

# %%
rec_v3

# %%
cursor

# %%
rec_v3, cursor = db.scan("Pages", fields=["title", "label", "children"], limit=3, use_v3=True)

# %%
rec_v3
# Out:
# [{'Id': 1, 'title': 'ГАДА', 'label': 'AGAD', 'children': [2, 3]},
#  {'Id': 2, 'title': 'ГАДА/350', 'label': 'AGAD/350', 'children': [4, 5]},
#  {'Id': 3, 'title': 'ГАДА/354', 'label': 'AGAD/354', 'children': [6]}]

# %%
rec_v3, cursor = db.scan("Pages", fields=["title", "label", "children"], limit=3)
# Out:
# 2026-07-08 16:41:19,849 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   localhost:api                         22.00     0.01    39.00       0.00           24
