# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.nocodb_database import (
    NocoDBDatabase,
    )

# %%
os.environ["NOCODB_API_TOKEN"]
# Out:
# 'sVKNl4WGKAFSoSaIsqQQLLyK8iiI3ZG_2MjAd3Ro'

# %%
db = NocoDBDatabase()

# %%
result, _ = db.scan("Pages", limit=10)
titles = set([record["title"] for record in result])
titles
# Out:
# {'ДАХеО/1',
#  'ДАХеО/1/1',
#  'ДАХеО/1/1/11',
#  'ДАХеО/1/1/19',
#  'ДАХеО/1/1/20',
#  'ДАХеО/1/2',
#  'ДАХеО/3',
#  'ДАХеО/4',
#  'ДАХеО/5',
#  'ДАХеО/Д'}

# %%
result, _ = db.scan("Documents", limit=200)
links = set([record["link"] for record in result])
#links

# %%
db.lookup("Pages", list(titles)[0])
# Out:
# 184

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Documents", list(links)[0])
# Out:
# 7

# %%
doc_ids = db.lookup("Documents", links)

# %%
doc_ids = db.lookup("Documents", links)

# %%
db.lookup("Pages", "foo")

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
len(db.lookup("Documents", links))
# Out:
# 100

# %%
db.read("Pages", db.lookup("Pages", 'ДАХеО/1/1/20'))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/1/1/20 ) LABEL::( ДАХеО/1/1/20 )',
#  'Id': 189,
#  'title': 'ДАХеО/1/1/20',
#  'description': 'Instructions of the Governor-General of Novorossiysk, reports of officials on clarifying the connections of the British citizen D. Melvel with the schismatics',
#  'availability': 'linked',
#  'level': 'case',
#  'comments': '(not on JRF)',
#  'label': '20',
#  'Pages_id': 185,
#  'years': '1854-1855',
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:47:09+00:00',
#  'UpdatedAt': '2025-09-25 03:01:45+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 185, 'title': 'ДАХеО/1/1'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
pages = db.read("Pages", list(db.lookup("Pages", titles).values()))
len(pages)
# Out:
# 10

# %%
docs = db.read("Documents", list(db.lookup("Documents", links).values()))
len(docs)
# Out:
# 100

# %%
db.read("Pages", [100000,])
# Out:
# [{}]

# %%
db.read("Pages", 100000)
# Out:
# {}

# %%
db.read("Pages", db.lookup("Pages", "ДАХеО/Д"))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/Д ) LABEL::( ДАХеО/Д )',
#  'Id': 180,
#  'title': 'ДАХеО/Д',
#  'description': 'State archive of Kherson region. Foundations of the pre-Soviet period',
#  'availability': 'linked',
#  'level': 'archive',
#  'comments': None,
#  'label': 'DAHEO-D',
#  'Pages_id': None,
#  'years': None,
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:40:29+00:00',
#  'UpdatedAt': '2025-09-25 03:02:38+00:00',
#  'change_date': '2025-08-21 00:00:00+00:00',
#  'reference_date': '2024-12-25 00:00:00+00:00',
#  'children': 154,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
doc=db.read("Documents", db.lookup("Documents", list(links)[0]))
doc
# Out:
# {'linked_title': 'URI::( https://uk.wikisource.org/wiki/Файл:ДАХеО_1-1-20._1855._Предписания_Новороссийского_генерал-губернатора,_рапорты_чиновников_о_выяснении_связей_британского_подданного.pdf ) LABEL::( Файл:ДАХеО_1-1-20._1855._Предписания_Новороссийского_генерал-губернатора,_рапорты_чиновников_о_выяснении_связей_британского_подданного.pdf )',
#  'Id': 7,
#  'file_name': 'Файл:ДАХеО_1-1-20._1855._Предписания_Новороссийского_генерал-губернатора,_рапорты_чиновников_о_выяснении_связей_британского_подданного.pdf',
#  'doc_type': ['O'],
#  'content_code': None,
#  'process_code': 'C2',
#  'processor': None,
#  'pages_processed': 0,
#  'comments': None,
#  'link': 'https://uk.wikisource.org/wiki/Файл:ДАХеО_1-1-20._1855._Предписания_Новороссийского_генерал-губернатора,_рапорты_чиновников_о_выяснении_связей_британского_подданного.pdf',
#  'Pages_id': 189,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______1-1-20._1855.____________________________________-___________,_____________________________________________________________.pdf.p1.w640_04UXj.jpg',
#    'title': '______1-1-20._1855.____________________________________-___________,_____________________________________________________________.pdf.p1.w640.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 126209,
#    'width': 640,
#    'height': 905,
#    'id': 'at9m3mnqjjfsesa4',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640_04UXj.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164342Z&X-Amz-Expires=7579&X-Amz-Signature=ff0fc4234fd2d97cede0ff96ea55ab1aabf40b8138a6b617fb9069a57decf8e0&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640_04UXj.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164342Z&X-Amz-Expires=7579&X-Amz-Signature=54f91cdce178346f6d5bf1723faea79fd6405fc1d0d276cd6f48b08f02055cf3&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640_04UXj.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164342Z&X-Amz-Expires=7579&X-Amz-Signature=521c82c66242bf13f9a839008a2b7eb55eca48471e489aaf3a84fa614656921f&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640_04UXj.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164341Z&X-Amz-Expires=7579&X-Amz-Signature=1d46acf9adcce44bb375e201fbb2803f17200c9ba499708b3a77bb3ecaf793ed&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______1-1-20._1855.____________________________________-___________%2C_____________________________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': True,
#  'CreatedAt': '2025-09-24 20:47:10+00:00',
#  'UpdatedAt': '2025-09-28 21:47:14+00:00',
#  'owning_page': {'Id': 189, 'title': 'ДАХеО/1/1/20'}}

# %%
test_page = {'title': 'test 1', "comments": "foo"}

# %%
rid = db.write("Pages", test_page)

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'foo',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2025-12-29 16:45:36+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
test_page = {'title': 'test 1', "comments": "bar"}

# %%
db.write("Pages", test_page)
# Out:
# 1544

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'bar',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2025-12-29 16:45:38+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
test_pages = [{"title": f"test {i}"} for i in range(20)]
test_pages
# Out:
# [{'title': 'test 0'},
#  {'title': 'test 1'},
#  {'title': 'test 2'},
#  {'title': 'test 3'},
#  {'title': 'test 4'},
#  {'title': 'test 5'},
#  {'title': 'test 6'},
#  {'title': 'test 7'},
#  {'title': 'test 8'},
#  {'title': 'test 9'},
#  {'title': 'test 10'},
#  {'title': 'test 11'},
#  {'title': 'test 12'},
#  {'title': 'test 13'},
#  {'title': 'test 14'},
#  {'title': 'test 15'},
#  {'title': 'test 16'},
#  {'title': 'test 17'},
#  {'title': 'test 18'},
#  {'title': 'test 19'}]

# %%
rids = db.write("Pages", test_pages)

# %%
[rec["title"] for rec in db.read("Pages", rids)]
# Out:
# ['test 0',
#  'test 1',
#  'test 2',
#  'test 3',
#  'test 4',
#  'test 5',
#  'test 6',
#  'test 7',
#  'test 8',
#  'test 9',
#  'test 10',
#  'test 11',
#  'test 12',
#  'test 13',
#  'test 14',
#  'test 15',
#  'test 16',
#  'test 17',
#  'test 18',
#  'test 19']

# %%
test_docs = [{"link": f"http://test.doc/{i}", "title": f"test doc {i}", "doc_type": ["O","C","L","V"]} for i in range(10)]
test_docs
# Out:
# [{'link': 'http://test.doc/0',
#   'title': 'test doc 0',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/1',
#   'title': 'test doc 1',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/2',
#   'title': 'test doc 2',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/3',
#   'title': 'test doc 3',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/4',
#   'title': 'test doc 4',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/5',
#   'title': 'test doc 5',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/6',
#   'title': 'test doc 6',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/7',
#   'title': 'test doc 7',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/8',
#   'title': 'test doc 8',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/9',
#   'title': 'test doc 9',
#   'doc_type': ['O', 'C', 'L', 'V']}]

# %%
dids = db.write("Documents", test_docs)
dids
# Out:
# [601, 605, 604, 607, 602, 609, 603, 608, 600, 606]

# %%
db.read("Pages",rids[0])
# Out:
# {'wiki_link': '',
#  'Id': 1554,
#  'title': 'test 0',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': None,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2025-12-29 16:45:40+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 6,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
db.read("Documents", dids[0])
# Out:
# {'linked_title': 'URI::( http://test.doc/0 ) LABEL::( test doc 0 )',
#  'Id': 601,
#  'file_name': 'test doc 0',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': None,
#  'link': 'http://test.doc/0',
#  'Pages_id': None,
#  'doc_image': None,
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-29 16:45:42+00:00',
#  'owning_page': None}

# %%
db.create_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 1"),
    db.lookup("Pages", "test 0"),
)

# %%
for i in range(10):
    db.create_links(
        "Documents", "owning_page", 
        db.lookup("Documents", f"http://test.doc/{i}"),
        db.lookup("Pages", f"test {i}"),
)

# %%
db.delete_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
    db.lookup("Pages", "test 0"),
)

# %%
db.get_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
)
# Out:
# []

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    db.lookup("Pages", "test 2"),
)

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    list(db.lookup("Pages", {f"test {i}" for i in range(3,7)}).values()),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1554]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1558]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# [1545]

# %%
db.delete_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# []

# %%
#db.delete("Pages", rids)

# %%
#db.delete("Documents", dids)

# %%
page = db.read("Pages", db.lookup("Pages", "test 6"))
page
# Out:
# {'wiki_link': '',
#  'Id': 1545,
#  'title': 'test 6',
#  'description': 'description update 3',
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2025-12-29 16:46:12+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
page["description"] = "description update 3"

# %%
db.write("Pages", page)
# Out:
# 1545

# %%
did = db.get_links("Pages", "doc_links", db.lookup("Pages", "test 6"))[0]

# %%
doc = db.read("Documents", did)
doc
# Out:
# {'linked_title': 'URI::( http://test.doc/6 ) LABEL::( test doc 6 )',
#  'Id': 603,
#  'file_name': 'test doc 6',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': 'new doc comment',
#  'link': 'http://test.doc/6',
#  'Pages_id': 1545,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_4VcwI.jpg',
#    'title': 'test_image_2.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 95727,
#    'width': 400,
#    'height': 332,
#    'id': 'atruzr6cy5gq7j5k',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_4VcwI.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164542Z&X-Amz-Expires=7458&X-Amz-Signature=8a2f468cc02986c935df651f8009b108b5e64c827416fcf8b6b7092b1f001ea5&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_4VcwI.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164542Z&X-Amz-Expires=7458&X-Amz-Signature=ac007291e768e1dc6dbc81cca03a355f703611b06e0d98b24faa6715f5d120ca&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_4VcwI.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164542Z&X-Amz-Expires=7458&X-Amz-Signature=dc61f6afffe0dbfedf60e2a443feed43a9fa20f3c2350700741ee28afe573150&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_4VcwI.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164542Z&X-Amz-Expires=7458&X-Amz-Signature=21a400848e6cccbd3774cd561cefb865c489067d8ec7aa074cdce51cb890ef39&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-29 16:45:42+00:00',
#  'owning_page': {'Id': 1545, 'title': 'test 6'}}

# %%
doc["comments"] = "new doc comment"

# %%
db.write("Documents", doc)
# Out:
# 603

# %%
doc["doc_type"] = None

# %%
db.write("Documents", doc)
# Out:
# 603

# %%
#db.delete("Pages", rids)
#db.delete("Documents", dids)

# %%
#db._upload_file("test/test_image.jpg")

# %%
db.set_attachments("Documents", did, "doc_image", ["test/test_image.jpg", "test/test_image_2.jpg"])

# %%
db.read("Documents", 603)
# Out:
# {'linked_title': 'URI::( http://test.doc/6 ) LABEL::( test doc 6 )',
#  'Id': 603,
#  'file_name': 'test doc 6',
#  'doc_type': [],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': 'new doc comment',
#  'link': 'http://test.doc/6',
#  'Pages_id': 1545,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_44PN0.jpg',
#    'title': 'test_image.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 87546,
#    'width': 459,
#    'height': 261,
#    'id': 'atq6vcscjuf0wxbx',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_44PN0.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=1fbc49d6c3973416a0d33f3b21caceaf56b05231c0a3f5883e23cd97c2ab40aa&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_44PN0.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=c8d25420e10e3290420794e45e0de4b2575f0105e7a1d62976df61854db33846&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_44PN0.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=5df3fc33e915335254a3f11c3d9e8449baf12f621ebd6ae2d20b0d5d40306c0a&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_44PN0.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=46631cc5b07d9c010c11c58b721c62d28afce788f7baef63603af0e98a419ee0&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#   {'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_3rkGk.jpg',
#    'title': 'test_image_2.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 95727,
#    'width': 400,
#    'height': 332,
#    'id': 'atsl6jwij05y1wc5',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_3rkGk.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=ae6505fd611f235f44326c9c1c29769e5181208ad567fa508994f92fb05d650a&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_3rkGk.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=cdd8e904c0a3e626466d526024b8ff8859f75277316d2a112e183e67e23c3112&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_3rkGk.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=3d4ebf0bcca47ee349679096e68ef88e20d39e82d700dfa710edd6f410d96667&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/29/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_3rkGk.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251229%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251229T164620Z&X-Amz-Expires=7420&X-Amz-Signature=0d75e7bacee9bd8fbc7228f9b8cb47aad3eaebc0bde391f71794220ab47359b4&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-29 16:46:20+00:00',
#  'owning_page': {'Id': 1545, 'title': 'test 6'}}

# %%
db.clear_attachments("Documents", did, "doc_image")

# %%
db.set_attachments("Documents", did, "doc_image", "test/test_image_2.jpg")
