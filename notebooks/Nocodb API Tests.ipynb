# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
import os
import requests
from birddog.nocodb_database import (
    _NOCODB_V2_API_ROOT,
    _NOCODB_BASE_ID,
    NocoDBDatabase,
    _validate_record,
    _records_url,
    )

from birddog.database import (
    Database,
    DatabaseError,
    FailedIO,
    FileNotFound,
    InvalidFieldName,
    InvalidFieldValue,
    InvalidRecordId,
    InvalidSourceId,
    InvalidTableName,
    InvalidTargetId,
    MissingKey,
)

# %%
db = NocoDBDatabase()

# %%
result, _ = db.scan("Pages", limit=10)
db.validate_records("Pages", result)
titles = set([record["title"] for record in result])
titles
# Out:
# {'ДАХеО/1',
#  'ДАХеО/1/1',
#  'ДАХеО/1/1/11',
#  'ДАХеО/1/1/19',
#  'ДАХеО/1/1/20',
#  'ДАХеО/1/2',
#  'ДАХеО/3',
#  'ДАХеО/4',
#  'ДАХеО/5',
#  'ДАХеО/Д'}

# %%
result, _ = db.scan("Documents", limit=200)
db.validate_records("Documents", result)
links = set([record["link"] for record in result])
#links

# %%
db.lookup("Pages", list(titles)[0])
# Out:
# 183

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/4': 183,
#  'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/4': 183,
#  'ДАХеО/Д': 180,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/3': 182,
#  'ДАХеО/1': 181,
#  'ДАХеО/1/1/20': 189,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1/19': 188}

# %%
db.lookup("Documents", list(links)[0])
# Out:
# 24

# %%
doc_ids = db.lookup("Documents", links)

# %%
doc_ids = db.lookup("Documents", links)

# %%
db.lookup("Pages", "foo")

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
len(db.lookup("Documents", links))
# Out:
# 100

# %%
#result = db.scan_all("Documents")

# %%
#len(result)

# %%
db.read("Pages",189)
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/1/1/20 ) LABEL::( ДАХеО/1/1/20 )',
#  'Id': 189,
#  'title': 'ДАХеО/1/1/20',
#  'description': 'Instructions of the Governor-General of Novorossiysk, reports of officials on clarifying the connections of the British citizen D. Melvel with the schismatics',
#  'availability': 'linked',
#  'level': 'case',
#  'comments': '(not on JRF)',
#  'label': '20',
#  'Pages_id': 185,
#  'years': '1854-1855',
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:47:09+00:00',
#  'UpdatedAt': '2025-09-25 03:01:45+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 185, 'title': 'ДАХеО/1/1'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
pages = db.read("Pages", list(db.lookup("Pages", titles).values()))
len(pages)
# Out:
# 10

# %%
docs = db.read("Documents", list(db.lookup("Documents", links).values()))
len(docs)
# Out:
# 100

# %%
db.read("Pages", [100000,])
# Out:
# [None]

# %%
db.read("Pages", 100000)

# %%
db.read("Pages", 189)
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/1/1/20 ) LABEL::( ДАХеО/1/1/20 )',
#  'Id': 189,
#  'title': 'ДАХеО/1/1/20',
#  'description': 'Instructions of the Governor-General of Novorossiysk, reports of officials on clarifying the connections of the British citizen D. Melvel with the schismatics',
#  'availability': 'linked',
#  'level': 'case',
#  'comments': '(not on JRF)',
#  'label': '20',
#  'Pages_id': 185,
#  'years': '1854-1855',
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:47:09+00:00',
#  'UpdatedAt': '2025-09-25 03:01:45+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 185, 'title': 'ДАХеО/1/1'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
db.read("Documents", 100)
# Out:
# {'linked_title': 'URI::( https://uk.wikisource.org/wiki/Файл:ДАХеО_14-1-778._1810-1817._Документи_\\(укази,_відомості,_листування,_плани\\)_про_відведення_землі_білоруським_переселенцям.pdf ) LABEL::( Файл:ДАХеО_14-1-778._1810-1817._Документи_\\(укази,_відомості,_листування,_плани\\)_про_відведення_землі_білоруським_переселенцям.pdf )',
#  'Id': 100,
#  'title': 'Файл:ДАХеО_14-1-778._1810-1817._Документи_(укази,_відомості,_листування,_плани)_про_відведення_землі_білоруським_переселенцям.pdf',
#  'doc_type': 'O',
#  'content_code': None,
#  'process_code': 'C1',
#  'processor': None,
#  'pages_processed': 0,
#  'comments': None,
#  'link': 'https://uk.wikisource.org/wiki/Файл:ДАХеО_14-1-778._1810-1817._Документи_(укази,_відомості,_листування,_плани)_про_відведення_землі_білоруським_переселенцям.pdf',
#  'Pages_id': 437,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-778._1810-1817.___________(_____,__________,___________,______)______________________________________________.pdf.p1.w640_ytJZ-.jpg',
#    'title': '______14-1-778._1810-1817.___________(_____,__________,___________,______)______________________________________________.pdf.p1.w640.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 250572,
#    'width': 640,
#    'height': 1145,
#    'id': 'atxjo33vkjkjetcb',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640_ytJZ-.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251225%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251225T002016Z&X-Amz-Expires=7786&X-Amz-Signature=e533dad89f0d5550cb386126e58e4d48142c6d9b0685dc449efee8c507c2a575&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640_ytJZ-.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251225%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251225T002016Z&X-Amz-Expires=7786&X-Amz-Signature=4a5407dc60bde5192070ff8bc3af892e0ddec877f2d79e401a249476f07c8d04&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640_ytJZ-.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251225%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251225T002016Z&X-Amz-Expires=7786&X-Amz-Signature=efd4a46e2e85ad1bb5c5b00e586b38f9cd995c420d9d038d8c3e3144593a18f8&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640_ytJZ-.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251225%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251225T002014Z&X-Amz-Expires=7787&X-Amz-Signature=7a6fdf75be1c53d4c2545af0840e5c85bb68730058cfef10a7cd1c20601594a0&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-778._1810-1817.___________%28_____%2C__________%2C___________%2C______%29______________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 23:51:59+00:00',
#  'UpdatedAt': '2025-09-25 21:10:05+00:00',
#  'owning_page': {'Id': 437, 'title': 'ДАХеО/14/1/778'}}

# %%
db = NocoDBDatabase()

# %%
test_page = {'title': 'test 1', "comments": "foo"}

# %%
db.write("Pages", test_page)
# Out:
# 1101

# %%
db.read("Pages", 1101)
# Out:
# {'wiki_link': '',
#  'Id': 1101,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'foo',
#  'label': None,
#  'Pages_id': None,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-25 00:14:01+00:00',
#  'UpdatedAt': '2025-12-25 00:22:26+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
test_page = {'title': 'test 1', "comments": "bar"}

# %%
db.write("Pages", test_page)
# Out:
# 1101

# %%
db.read("Pages", 1101)
# Out:
# {'wiki_link': '',
#  'Id': 1101,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'bar',
#  'label': None,
#  'Pages_id': None,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-25 00:14:01+00:00',
#  'UpdatedAt': '2025-12-25 00:22:27+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
test_pages = [{"title": f"test {i}"} for i in range(20)]
test_pages
# Out:
# [{'title': 'test 0'},
#  {'title': 'test 1'},
#  {'title': 'test 2'},
#  {'title': 'test 3'},
#  {'title': 'test 4'},
#  {'title': 'test 5'},
#  {'title': 'test 6'},
#  {'title': 'test 7'},
#  {'title': 'test 8'},
#  {'title': 'test 9'},
#  {'title': 'test 10'},
#  {'title': 'test 11'},
#  {'title': 'test 12'},
#  {'title': 'test 13'},
#  {'title': 'test 14'},
#  {'title': 'test 15'},
#  {'title': 'test 16'},
#  {'title': 'test 17'},
#  {'title': 'test 18'},
#  {'title': 'test 19'}]

# %%
rids = db.write("Pages", test_pages)

# %%
[rec["title"] for rec in db.read("Pages", rids)]
# Out:
# ['test 0',
#  'test 1',
#  'test 2',
#  'test 3',
#  'test 4',
#  'test 5',
#  'test 6',
#  'test 7',
#  'test 8',
#  'test 9',
#  'test 10',
#  'test 11',
#  'test 12',
#  'test 13',
#  'test 14',
#  'test 15',
#  'test 16',
#  'test 17',
#  'test 18',
#  'test 19']

# %%
db.validate_records("Pages", [db.read("Pages", db.lookup("Pages", "test 1"))])

# %%
db._table_id_map
# Out:
# {'Users': 'm8xe480su6isthp',
#  'Pages': 'mtrj7h4scl3s15b',
#  'Documents': 'm676bm10pfq3hwk',
#  'Schema': 'me977l7rh0fkbxf',
#  'Schema Values': 'm8rr0x0vtf989pp'}
