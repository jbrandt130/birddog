# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.nocodb_database import (
    NocoDBDatabase,
    )

# %%
db = NocoDBDatabase()

# %%
result, _ = db.scan("Pages", limit=10)
db.validate_records("Pages", result)
titles = set([record["title"] for record in result])
titles
# Out:
# {'ДАХеО/1',
#  'ДАХеО/1/1',
#  'ДАХеО/1/1/11',
#  'ДАХеО/1/1/19',
#  'ДАХеО/1/1/20',
#  'ДАХеО/1/2',
#  'ДАХеО/3',
#  'ДАХеО/4',
#  'ДАХеО/5',
#  'ДАХеО/Д'}

# %%
result, _ = db.scan("Documents", limit=200)
db.validate_records("Documents", result)
links = set([record["link"] for record in result])
#links

# %%
db.lookup("Pages", list(titles)[0])
# Out:
# 183

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Pages", titles)
# Out:
# {'ДАХеО/Д': 180,
#  'ДАХеО/1': 181,
#  'ДАХеО/3': 182,
#  'ДАХеО/4': 183,
#  'ДАХеО/5': 184,
#  'ДАХеО/1/1': 185,
#  'ДАХеО/1/2': 186,
#  'ДАХеО/1/1/11': 187,
#  'ДАХеО/1/1/19': 188,
#  'ДАХеО/1/1/20': 189}

# %%
db.lookup("Documents", list(links)[0])
# Out:
# 63

# %%
doc_ids = db.lookup("Documents", links)

# %%
doc_ids = db.lookup("Documents", links)

# %%
db.lookup("Pages", "foo")

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
db.lookup("Pages", {"foo", "bar"})
# Out:
# {}

# %%
len(db.lookup("Documents", links))
# Out:
# 100

# %%
db.read("Pages", db.lookup("Pages", 'ДАХеО/1/1/20'))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/1/1/20 ) LABEL::( ДАХеО/1/1/20 )',
#  'Id': 189,
#  'title': 'ДАХеО/1/1/20',
#  'description': 'Instructions of the Governor-General of Novorossiysk, reports of officials on clarifying the connections of the British citizen D. Melvel with the schismatics',
#  'availability': 'linked',
#  'level': 'case',
#  'comments': '(not on JRF)',
#  'label': '20',
#  'Pages_id': 185,
#  'years': '1854-1855',
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:47:09+00:00',
#  'UpdatedAt': '2025-09-25 03:01:45+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 185, 'title': 'ДАХеО/1/1'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
pages = db.read("Pages", list(db.lookup("Pages", titles).values()))
len(pages)
# Out:
# 10

# %%
docs = db.read("Documents", list(db.lookup("Documents", links).values()))
len(docs)
# Out:
# 100

# %%
db.read("Pages", [100000,])
# Out:
# [{}]

# %%
db.read("Pages", 100000)
# Out:
# {}

# %%
db.read("Pages", db.lookup("Pages", "ДАХеО/Д"))
# Out:
# {'wiki_link': 'URI::( https://uk.wikisource.org/wiki/%D0%90%D1%80%D1%85%D1%96%D0%B2:ДАХеО/Д ) LABEL::( ДАХеО/Д )',
#  'Id': 180,
#  'title': 'ДАХеО/Д',
#  'description': 'State archive of Kherson region. Foundations of the pre-Soviet period',
#  'availability': 'linked',
#  'level': 'archive',
#  'comments': None,
#  'label': 'DAHEO-D',
#  'Pages_id': None,
#  'years': None,
#  'source_type': 'wiki',
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 20:40:29+00:00',
#  'UpdatedAt': '2025-09-25 03:02:38+00:00',
#  'change_date': '2025-08-21 00:00:00+00:00',
#  'reference_date': '2024-12-25 00:00:00+00:00',
#  'children': 154,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
doc=db.read("Documents", db.lookup("Documents", list(links)[0]))
doc
# Out:
# {'linked_title': 'URI::( https://uk.wikisource.org/wiki/Файл:ДАХеО_14-1-332._1797._Укази_Новоросійської_губернської_канцелярії,_Вознесенського_намісницького_правління_та_ін.pdf ) LABEL::( Файл:ДАХеО_14-1-332._1797._Укази_Новоросійської_губернської_канцелярії,_Вознесенського_намісницького_правління_та_ін.pdf )',
#  'Id': 63,
#  'title': 'Файл:ДАХеО_14-1-332._1797._Укази_Новоросійської_губернської_канцелярії,_Вознесенського_намісницького_правління_та_ін.pdf',
#  'doc_type': ['O'],
#  'content_code': None,
#  'process_code': 'C2',
#  'processor': None,
#  'pages_processed': 0,
#  'comments': None,
#  'link': 'https://uk.wikisource.org/wiki/Файл:ДАХеО_14-1-332._1797._Укази_Новоросійської_губернської_канцелярії,_Вознесенського_намісницького_правління_та_ін.pdf',
#  'Pages_id': 399,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-332._1797.____________________________________________,_____________________________________________.pdf.p1.w640_Hmm9Z.jpg',
#    'title': '______14-1-332._1797.____________________________________________,_____________________________________________.pdf.p1.w640.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 103277,
#    'width': 640,
#    'height': 905,
#    'id': 'athou1t3mln2bpi7',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640_Hmm9Z.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T054207Z&X-Amz-Expires=7674&X-Amz-Signature=ebff3c3e11b5abe78815d6b2edd4cc81933dec65f1295546b34b968959a05a2a&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640_Hmm9Z.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T054207Z&X-Amz-Expires=7674&X-Amz-Signature=3e878796c274e023bc14b18f2014e37bb21dbae69d9b626fa412e93360bd9b21&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640_Hmm9Z.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T054207Z&X-Amz-Expires=7674&X-Amz-Signature=31f11fa330d3cca2401943ab8a93ad3a1430d9c7634cc1f28a93d8ba84e8a9e4&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/09/25/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640_Hmm9Z.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T054205Z&X-Amz-Expires=7675&X-Amz-Signature=7d815eec86ce443a10928acbe51cd7168240acb6b7d4fdd5528179335eb44741&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22______14-1-332._1797.____________________________________________%2C_____________________________________________.pdf.p1.w640.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-09-24 23:50:28+00:00',
#  'UpdatedAt': '2025-09-25 21:06:37+00:00',
#  'owning_page': {'Id': 399, 'title': 'ДАХеО/14/1/332'}}

# %%
test_page = {'title': 'test 1', "comments": "foo"}

# %%
rid = db.write("Pages", test_page)

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'foo',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2025-12-27 05:49:52+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
test_page = {'title': 'test 1', "comments": "bar"}

# %%
db.write("Pages", test_page)
# Out:
# 1544

# %%
db.read("Pages", rid)
# Out:
# {'wiki_link': '',
#  'Id': 1544,
#  'title': 'test 1',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': 'bar',
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:55+00:00',
#  'UpdatedAt': '2025-12-27 05:49:54+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
test_pages = [{"title": f"test {i}"} for i in range(20)]
test_pages
# Out:
# [{'title': 'test 0'},
#  {'title': 'test 1'},
#  {'title': 'test 2'},
#  {'title': 'test 3'},
#  {'title': 'test 4'},
#  {'title': 'test 5'},
#  {'title': 'test 6'},
#  {'title': 'test 7'},
#  {'title': 'test 8'},
#  {'title': 'test 9'},
#  {'title': 'test 10'},
#  {'title': 'test 11'},
#  {'title': 'test 12'},
#  {'title': 'test 13'},
#  {'title': 'test 14'},
#  {'title': 'test 15'},
#  {'title': 'test 16'},
#  {'title': 'test 17'},
#  {'title': 'test 18'},
#  {'title': 'test 19'}]

# %%
rids = db.write("Pages", test_pages)

# %%
[rec["title"] for rec in db.read("Pages", rids)]
# Out:
# ['test 0',
#  'test 1',
#  'test 2',
#  'test 3',
#  'test 4',
#  'test 5',
#  'test 6',
#  'test 7',
#  'test 8',
#  'test 9',
#  'test 10',
#  'test 11',
#  'test 12',
#  'test 13',
#  'test 14',
#  'test 15',
#  'test 16',
#  'test 17',
#  'test 18',
#  'test 19']

# %%
db.validate_records("Pages", [db.read("Pages", db.lookup("Pages", "test 1"))])

# %%
test_docs = [{"link": f"http://test.doc/{i}", "title": f"test doc {i}", "doc_type": ["O","C","L","V"]} for i in range(10)]
test_docs
# Out:
# [{'link': 'http://test.doc/0',
#   'title': 'test doc 0',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/1',
#   'title': 'test doc 1',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/2',
#   'title': 'test doc 2',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/3',
#   'title': 'test doc 3',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/4',
#   'title': 'test doc 4',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/5',
#   'title': 'test doc 5',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/6',
#   'title': 'test doc 6',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/7',
#   'title': 'test doc 7',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/8',
#   'title': 'test doc 8',
#   'doc_type': ['O', 'C', 'L', 'V']},
#  {'link': 'http://test.doc/9',
#   'title': 'test doc 9',
#   'doc_type': ['O', 'C', 'L', 'V']}]

# %%
dids = db.write("Documents", test_docs)
dids
# Out:
# [601, 605, 604, 607, 602, 609, 603, 608, 600, 606]

# %%
db.read("Pages",rids[0])
# Out:
# {'wiki_link': '',
#  'Id': 1554,
#  'title': 'test 0',
#  'description': None,
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': None,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2025-12-27 05:49:55+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 6,
#  'parent': None,
#  'doc_links': 0,
#  'doc_pages_processed': 0}

# %%
db.read("Documents", dids[0])
# Out:
# {'linked_title': 'URI::( http://test.doc/0 ) LABEL::( test doc 0 )',
#  'Id': 601,
#  'title': 'test doc 0',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': None,
#  'link': 'http://test.doc/0',
#  'Pages_id': None,
#  'doc_image': None,
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-27 05:49:57+00:00',
#  'owning_page': None}

# %%
db.create_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 1"),
    db.lookup("Pages", "test 0"),
)

# %%
for i in range(10):
    db.create_links(
        "Documents", "owning_page", 
        db.lookup("Documents", f"http://test.doc/{i}"),
        db.lookup("Pages", f"test {i}"),
)

# %%
db.delete_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
    db.lookup("Pages", "test 0"),
)

# %%
db.get_links(
    "Documents", "owning_page", 
    db.lookup("Documents", "http://test.doc/0"),
)
# Out:
# []

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    db.lookup("Pages", "test 2"),
)

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
    list(db.lookup("Pages", {f"test {i}" for i in range(3,7)}).values()),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 0"),
)
# Out:
# [1544, 1545, 1546, 1557, 1561, 1563]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1554]

# %%
db.create_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
)
# Out:
# [1558]

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# [1545]

# %%
db.delete_links(
    "Pages", "children", 
    db.lookup("Pages", "test 6"),
    db.lookup("Pages", "test 7"),
)

# %%
db.get_links(
    "Pages", "parent", 
    db.lookup("Pages", "test 7"),
)
# Out:
# []

# %%
#db.delete("Pages", rids)

# %%
#db.delete("Documents", dids)

# %%
page = db.read("Pages", db.lookup("Pages", "test 6"))
page
# Out:
# {'wiki_link': '',
#  'Id': 1545,
#  'title': 'test 6',
#  'description': 'description update 3',
#  'availability': None,
#  'level': None,
#  'comments': None,
#  'label': None,
#  'Pages_id': 1554,
#  'years': None,
#  'source_type': None,
#  'birddog_alert': None,
#  'CreatedAt': '2025-12-26 23:18:58+00:00',
#  'UpdatedAt': '2025-12-27 05:50:25+00:00',
#  'change_date': None,
#  'reference_date': None,
#  'children': 0,
#  'parent': {'Id': 1554, 'title': 'test 0'},
#  'doc_links': 1,
#  'doc_pages_processed': 0}

# %%
page["description"] = "description update 3"

# %%
db.write("Pages", page)
# Out:
# 1545

# %%
did = db.get_links("Pages", "doc_links", db.lookup("Pages", "test 6"))[0]

# %%
doc = db.read("Documents", did)
doc
# Out:
# {'linked_title': 'URI::( http://test.doc/6 ) LABEL::( test doc 6 )',
#  'Id': 603,
#  'title': 'test doc 6',
#  'doc_type': ['O', 'C', 'L', 'V'],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': 'new doc comment',
#  'link': 'http://test.doc/6',
#  'Pages_id': 1545,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_G-2tI.jpg',
#    'title': 'test_image_2.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 95727,
#    'width': 400,
#    'height': 332,
#    'id': 'at0plf30c98qiffn',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_G-2tI.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055010Z&X-Amz-Expires=7790&X-Amz-Signature=a9d797ec5da89cc66ca3a79d02b74aa5887167fc17e96dbdb3dcb1f0b5f80fcc&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_G-2tI.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055010Z&X-Amz-Expires=7790&X-Amz-Signature=8f0358cafb5376f582fcd8640c3c84852a561c4aebe3cf154744b148828ea467&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_G-2tI.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055010Z&X-Amz-Expires=7790&X-Amz-Signature=d02c93c9b503f1b7e713565a3775151550339ec219a7b249af6eb02fca969918&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_G-2tI.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055010Z&X-Amz-Expires=7790&X-Amz-Signature=2d039de7f5697afe9851e6215fb0c78b274452c17cc15dbc635c71e1b2c8a432&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-27 05:49:58+00:00',
#  'owning_page': {'Id': 1545, 'title': 'test 6'}}

# %%
doc["comments"] = "new doc comment"

# %%
db.write("Documents", doc)
# Out:
# 603

# %%
doc["doc_type"] = None

# %%
db.write("Documents", doc)
# Out:
# 603

# %%
#db.delete("Pages", rids)
#db.delete("Documents", dids)

# %%
#db._upload_file("test/test_image.jpg")

# %%
db.set_attachments("Documents", did, "doc_image", ["test/test_image.jpg", "test/test_image_2.jpg"])

# %%
db.read("Documents", 603)
# Out:
# {'linked_title': 'URI::( http://test.doc/6 ) LABEL::( test doc 6 )',
#  'Id': 603,
#  'title': 'test doc 6',
#  'doc_type': [],
#  'content_code': None,
#  'process_code': 'FX',
#  'processor': None,
#  'pages_processed': None,
#  'comments': 'new doc comment',
#  'link': 'http://test.doc/6',
#  'Pages_id': 1545,
#  'doc_image': [{'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_68Ep8.jpg',
#    'title': 'test_image.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 87546,
#    'width': 459,
#    'height': 261,
#    'id': 'ata0rxfvekb69rpu',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_68Ep8.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=c253883b5e55d9ad901ffd5eda0e66be7331264b91ada2fc4a864a1ec64b2270&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_68Ep8.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=55cd1c20f1f33141b259d963f87b6fcb38906bc8a4e762762a32fd34231ff92f&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_68Ep8.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=50700cd8daa92ce57fa17418fbc8e28b4811a3b1b5813157bcf2bb6a9d764b7e&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_68Ep8.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=bb6a4fdc09e9e89755771f83f555516ef24c0933c4e636289a9feef670371bc7&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#   {'url': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_Z6JI5.jpg',
#    'title': 'test_image_2.jpg',
#    'mimetype': 'image/jpeg',
#    'size': 95727,
#    'width': 400,
#    'height': 332,
#    'id': 'at076nmjh16uazqy',
#    'thumbnails': {'tiny': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_Z6JI5.jpg/tiny.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=ea12184f353fddc1cdb9cafc91da2930bb43eb9573e77bb7271c0fcf403d5c6c&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'small': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_Z6JI5.jpg/small.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=dda37cca7df259f666badf80b9111ee5cd4df1f9d7ce68891d53c43410e67e9d&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'},
#     'card_cover': {'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/thumbnails/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_Z6JI5.jpg/card_cover.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=791d94ffffb49c7163a76c9e6049a331aa7262ea384d68970df05f7fb553fddd&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}},
#    'signedUrl': 'https://nocohub-001-prod-app-attachments.s3.us-east-2.amazonaws.com/nc/uploads/2025/12/27/870fb1836d3da66d73fff491f2be8eb3e4e14e8a/test_image_2_Z6JI5.jpg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIATUJCOBWTFSXT22F2%2F20251227%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20251227T055031Z&X-Amz-Expires=7769&X-Amz-Signature=c1b8f72a2d72a60fd7e8f9f936e87ee36fd1afb8db9147c9bd6d3fd93b06dfdc&X-Amz-SignedHeaders=host&response-content-disposition=inline%3B%20filename%3D%22test_image_2.jpg%22&response-content-type=image%2Fjpeg&x-amz-checksum-mode=ENABLED&x-id=GetObject'}],
#  'birddog_alert': False,
#  'CreatedAt': '2025-12-26 23:19:00+00:00',
#  'UpdatedAt': '2025-12-27 05:50:31+00:00',
#  'owning_page': {'Id': 1545, 'title': 'test 6'}}

# %%
db.clear_attachments("Documents", did, "doc_image")

# %%
db.set_attachments("Documents", did, "doc_image", "test/test_image_2.jpg")
