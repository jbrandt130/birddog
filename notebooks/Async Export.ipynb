# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.runtime import Runtime
from birddog.excel import ExportManager
# Out:
# 2025-11-12 12:00:40,151 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.
# 2025-11-12 12:00:40,698 [INFO] Translation is enabled. Using GCP translator
# 2025-11-12 12:00:40,699 [INFO] Using Google Cloud translation API
# 2025-11-12 12:00:40,699 [INFO] GoogleCloudTranslator using REST API

# %%
runtime = Runtime()
manager = ExportManager(runtime)

# %%
title = 'Архів:ДАХмО/Р-6193/12/10423–16825'
template = 'opus.xlsx'
table_name = 'Table 1'
column_map = {
    'ID': [1],
    'DESCRIPTION': [2],
    'DATE': [3]
}

# %%
id = manager.export_page(
    title, 
    table_name=table_name, 
    template=template, 
    column_map=column_map)

# %%
manager.is_complete(id)

# %%
output = manager.get_result(id)

# %%
id = manager.export_page(
    title,
    compare="2025,01,16,13:29",
    table_name=table_name, 
    template=template, 
    column_map=column_map)

# %%
manager.is_complete(id)

# %%
output = manager.get_result(id)

# %%
output.seek(0)

# %%
with open("foo2.xlsx", "wb") as f:
    f.write(output.read())

# %%
from io import BytesIO

# %%
x = BytesIO()

# %%
len(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(x)
#
# TypeError: object of type '_io.BytesIO' has no len()

# %%
len(x.read())
# Out:
# 0

# %%
x.write(b'123')
# Out:
# 3

# %%
x.seek(0)
# Out:
# 0

# %%
len(x.read())
# Out:
# 3
