# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.database_importer import (
    import_spreadsheet,
    process_dir,
)
# Out:
# 2026-02-11 15:49:45,442 [INFO] Using aws nocodb api: http://nocodb-env.eba-xhmfyydr.us-east-2.elasticbeanstalk.com
# 2026-02-11 15:49:45,543 [INFO] Translation is enabled. Using GCP translator
# 2026-02-11 15:49:45,544 [INFO] Using Google Cloud translation API
# 2026-02-11 15:49:45,545 [INFO] GoogleCloudTranslator using REST API

# %%
file1 = "var/WAT/DAHO (Kharkiv)/DAHO-R-wiki-20260126.xlsx"
file2 = "var/WAT/DAHO (Kharkiv)/DAHO-D-wiki-20260206.xlsx"
file3 = "var/WAT/DADO (Donetsk)/DADO-D-wiki-20251027.xlsx"
file4 = "var/WAT/CDIAK (UKR history)/CDIAK-wiki-20260206.xlsx"

# %%
#import_spreadsheet(file2)

# %%
#import_spreadsheet(file1)

# %%
#import_spreadsheet(file3)

# %%
import_spreadsheet(file4)
# Out:
# 2026-02-11 15:49:45,887 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# 2026-02-11 15:49:55,259 [INFO] processing worksheet: CDIAK wiki fund list
# 2026-02-11 15:49:55,263 [INFO] processing worksheet: fund 2
# 2026-02-11 15:49:55,263 [INFO] processing worksheet: CDIAK 2-1
# 2026-02-11 15:49:55,270 [INFO] processing worksheet: fund 3
# 2026-02-11 15:49:55,270 [INFO] processing worksheet: CDIAK 3-1
# 2026-02-11 15:49:55,273 [INFO] processing worksheet: fund 8
# 2026-02-11 15:49:55,273 [INFO] processing worksheet: CDIAK 8-1
# 2026-02-11 15:49:55,274 [INFO] processing worksheet: fund 11
# 2026-02-11 15:49:55,275 [INFO] processing worksheet: CDIAK 11-1
# 2026-02-11 15:49:55,281 [INFO] processing worksheet: fund 25
# 2026-02-11 15:49:55,281 [INFO] processing worksheet: CDIAK 25-1
# 2026-02-11 15:49:55,284 [INFO] processing worksheet: fund 26
# 2026-02-11 15:49:55,284 [INFO] processing worksheet: CDIAK 26-1
# 2026-02-11 15:49:55,285 [INFO] processing worksheet: fund 28
# 2026-02-11 15:49:55,285 [INFO] processing worksheet: CDIAK 28-1
# 2026-02-11 15:49:55,289 [INFO] processing worksheet: fund 34
# 2026-02-11 15:49:55,289 [INFO] processing worksheet: CDIAK 34-1
# 2026-02-11 15:49:55,290 [INFO] processing worksheet: fund 44
# 2026-02-11 15:49:55,291 [INFO] processing worksheet: CDIAK 44-1
# 2026-02-11 15:49:55,292 [INFO] processing worksheet: fund 49
# 2026-02-11 15:49:55,292 [INFO] processing worksheet: CDIAK 49-1
# 2026-02-11 15:49:55,293 [INFO] processing worksheet: CDIAK 49-2
# 2026-02-11 15:49:55,294 [INFO] processing worksheet: CDIAK 49-3
# 2026-02-11 15:49:55,295 [INFO] processing worksheet: fund 53
# 2026-02-11 15:49:55,295 [INFO] processing worksheet: CDIAK 53-2
# 2026-02-11 15:49:55,296 [INFO] processing worksheet: fund 57
# 2026-02-11 15:49:55,297 [INFO] processing worksheet: CDIAK 57-1
# 2026-02-11 15:49:55,319 [INFO] processing worksheet: fund 127
# 2026-02-11 15:49:55,334 [INFO] processing worksheet: CDIAK 127-235
# 2026-02-11 15:49:55,338 [INFO] processing worksheet: CDIAK 127-683
# 2026-02-11 15:49:55,339 [INFO] processing worksheet: CDIAK 127-699
# 2026-02-11 15:49:55,339 [WARNING] cannot determine page title: sheet='CDIAK 127-699'', cell=D3 (skipping)
# 2026-02-11 15:49:55,339 [INFO] processing worksheet: CDIAK 127-1020
# 2026-02-11 15:49:55,340 [INFO] processing worksheet: fund 170
# 2026-02-11 15:49:55,340 [INFO] processing worksheet: CDIAK 170-1
# 2026-02-11 15:49:55,341 [INFO] processing worksheet: fund 193
# 2026-02-11 15:49:55,341 [INFO] processing worksheet: CDIAK 193-1
# 2026-02-11 15:49:55,342 [INFO] processing worksheet: fund 199
# 2026-02-11 15:49:55,343 [WARNING] cannot determine page title: sheet='fund 199'', row=7 (skipping)
# 2026-02-11 15:49:55,343 [WARNING] cannot determine page title: sheet='fund 199'', row=8 (skipping)
# 2026-02-11 15:49:55,343 [INFO] processing worksheet: CDIAK 199-1
# 2026-02-11 15:49:55,344 [INFO] processing worksheet: fund 202
# 2026-02-11 15:49:55,344 [INFO] processing worksheet: CDIAK 202-1
# 2026-02-11 15:49:55,345 [INFO] processing worksheet: fund 236
# 2026-02-11 15:49:55,345 [INFO] processing worksheet: CDIAK 236-2
# 2026-02-11 15:49:55,347 [INFO] processing worksheet: fund 241
# 2026-02-11 15:49:55,348 [INFO] processing worksheet: CDIAK 241-1
# 2026-02-11 15:49:55,352 [INFO] processing worksheet: fund 257
# 2026-02-11 15:49:55,352 [INFO] processing worksheet: CDIAK 257-1
# 2026-02-11 15:49:55,353 [INFO] processing worksheet: fund 268
# 2026-02-11 15:49:55,353 [INFO] processing worksheet: CDIAK 268-1
# 2026-02-11 15:49:55,354 [INFO] processing worksheet: fund 274
# 2026-02-11 15:49:55,355 [INFO] processing worksheet: CDIAK 274-1
# 2026-02-11 15:49:55,356 [INFO] processing worksheet: fund 275
# 2026-02-11 15:49:55,356 [INFO] processing worksheet: CDIAK 275-1
# 2026-02-11 15:49:55,357 [INFO] processing worksheet: fund 276
# 2026-02-11 15:49:55,357 [INFO] processing worksheet: CDIAK 276-1
# 2026-02-11 15:49:55,358 [INFO] processing worksheet: fund 289
# 2026-02-11 15:49:55,359 [INFO] processing worksheet: CDIAK 289-1
# 2026-02-11 15:49:55,360 [INFO] processing worksheet: fund 301
# 2026-02-11 15:49:55,360 [INFO] processing worksheet: CDIAK 301-1
# 2026-02-11 15:49:55,361 [INFO] processing worksheet: fund 317
# 2026-02-11 15:49:55,361 [INFO] processing worksheet: CDIAK 317-1
# 2026-02-11 15:49:55,362 [INFO] processing worksheet: CDIAK 317-4
# 2026-02-11 15:49:55,363 [INFO] processing worksheet: fund 318
# 2026-02-11 15:49:55,364 [INFO] processing worksheet: CDIAK 318-1t2
# 2026-02-11 15:49:55,365 [INFO] processing worksheet: CDIAK 318-5
# 2026-02-11 15:49:55,366 [INFO] processing worksheet: fund 442
# 2026-02-11 15:49:55,378 [INFO] processing worksheet: CDIAK 442-1
# 2026-02-11 15:49:55,380 [INFO] processing worksheet: CDIAK 442-32
# 2026-02-11 15:49:55,380 [INFO] processing worksheet: CDIAK 442-33
# 2026-02-11 15:49:55,380 [INFO] processing worksheet: CDIAK 442-37
# 2026-02-11 15:49:55,382 [INFO] processing worksheet: CDIAK 442-67
# 2026-02-11 15:49:55,383 [INFO] processing worksheet: CDIAK 442-73
# 2026-02-11 15:49:55,384 [INFO] processing worksheet: CDIAK 442-80
# 2026-02-11 15:49:55,385 [INFO] processing worksheet: CDIAK 442-84
# 2026-02-11 15:49:55,386 [INFO] processing worksheet: CDIAK 442-89
# 2026-02-11 15:49:55,387 [INFO] processing worksheet: CDIAK 442-150
# 2026-02-11 15:49:55,388 [INFO] processing worksheet: CDIAK 442-153
# 2026-02-11 15:49:55,389 [INFO] processing worksheet: CDIAK 442-169
# 2026-02-11 15:49:55,390 [INFO] processing worksheet: CDIAK 442-194
# 2026-02-11 15:49:55,391 [INFO] processing worksheet: CDIAK 442-195
# 2026-02-11 15:49:55,392 [INFO] processing worksheet: CDIAK 442-196
# 2026-02-11 15:49:55,393 [INFO] processing worksheet: CDIAK 442-197
# 2026-02-11 15:49:55,394 [INFO] processing worksheet: CDIAK 442-198
# 2026-02-11 15:49:55,396 [INFO] processing worksheet: CDIAK 442-550
# 2026-02-11 15:49:55,397 [INFO] processing worksheet: CDIAK 442-659
# 2026-02-11 15:49:55,398 [INFO] processing worksheet: CDIAK 442-661
# 2026-02-11 15:49:55,399 [INFO] processing worksheet: CDIAK 442-665
# 2026-02-11 15:49:55,400 [INFO] processing worksheet: CDIAK 442-789
# 2026-02-11 15:49:55,401 [INFO] processing worksheet: CDIAK 442-855
# 2026-02-11 15:49:55,402 [INFO] processing worksheet: fund 445
# 2026-02-11 15:49:55,402 [INFO] processing worksheet: CDIAK 445-1
# 2026-02-11 15:49:55,403 [INFO] processing worksheet: fund 486
# 2026-02-11 15:49:55,404 [INFO] processing worksheet: CDIAK 486-1
# 2026-02-11 15:49:55,406 [INFO] processing worksheet: CDIAK 486-3T2
# 2026-02-11 15:49:55,407 [INFO] processing worksheet: CDIAK 486-9
# 2026-02-11 15:49:55,407 [INFO] processing worksheet: fund 491
# 2026-02-11 15:49:55,408 [INFO] processing worksheet: CDIAK 491-75
# 2026-02-11 15:49:55,408 [INFO] processing worksheet: CDIAK 491-94
# 2026-02-11 15:49:55,410 [INFO] processing worksheet: CDIAK 491-96
# 2026-02-11 15:49:55,412 [INFO] processing worksheet: fund 510
# 2026-02-11 15:49:55,412 [INFO] processing worksheet: CDIAK 510-1
# 2026-02-11 15:49:55,413 [INFO] processing worksheet: fund 514
# 2026-02-11 15:49:55,413 [INFO] processing worksheet: CDIAK 514-1
# 2026-02-11 15:49:55,414 [INFO] processing worksheet: fund 515
# 2026-02-11 15:49:55,414 [INFO] processing worksheet: CDIAK 515-1
# 2026-02-11 15:49:55,415 [INFO] processing worksheet: fund 663
# 2026-02-11 15:49:55,416 [INFO] processing worksheet: CDIAK 663-1
# 2026-02-11 15:49:55,418 [INFO] processing worksheet: fund 693
# 2026-02-11 15:49:55,419 [INFO] processing worksheet: CDIAK 693-1
# 2026-02-11 15:49:55,420 [INFO] processing worksheet: fund 707
# 2026-02-11 15:49:55,423 [INFO] processing worksheet: CDIAK 707-62
# 2026-02-11 15:49:55,424 [INFO] processing worksheet: CDIAK 707-86
# 2026-02-11 15:49:55,425 [INFO] processing worksheet: CDIAK 707-223
# 2026-02-11 15:49:55,426 [INFO] processing worksheet: CDIAK 707-229
# 2026-02-11 15:49:55,427 [INFO] processing worksheet: CDIAK 707-285
# 2026-02-11 15:49:55,428 [INFO] processing worksheet: CDIAK 707-287
# 2026-02-11 15:49:55,428 [INFO] processing worksheet: CDIAK 707-296
# 2026-02-11 15:49:55,429 [INFO] processing worksheet: fund 719
# 2026-02-11 15:49:55,430 [INFO] processing worksheet: CDIAK 719-2
# 2026-02-11 15:49:55,431 [INFO] processing worksheet: fund 730
# 2026-02-11 15:49:55,431 [INFO] processing worksheet: CDIAK 730-1
# 2026-02-11 15:49:55,432 [INFO] processing worksheet: fund 789
# 2026-02-11 15:49:55,432 [INFO] processing worksheet: CDIAK 789-2
# 2026-02-11 15:49:55,433 [INFO] processing worksheet: fund 1010
# 2026-02-11 15:49:55,433 [INFO] processing worksheet: CDIAK 1010-1
# 2026-02-11 15:49:55,434 [INFO] processing worksheet: fund 1089
# 2026-02-11 15:49:55,434 [INFO] processing worksheet: CDIAK 1089-1
# 2026-02-11 15:49:55,435 [INFO] processing worksheet: fund 1150
# 2026-02-11 15:49:55,435 [INFO] processing worksheet: CDIAK 1150-1
# 2026-02-11 15:49:55,439 [INFO] processing worksheet: fund 1158
# 2026-02-11 15:49:55,440 [INFO] processing worksheet: CDIAK 1158-1
# 2026-02-11 15:49:55,443 [INFO] processing worksheet: fund 1159
# 2026-02-11 15:49:55,444 [INFO] processing worksheet: CDIAK 1159-1c (old #s)
# 2026-02-11 15:49:55,446 [INFO] processing worksheet: CDIAK 1159-1 (new #s)
# 2026-02-11 15:49:55,448 [INFO] processing worksheet: fund 1160
# 2026-02-11 15:49:55,448 [INFO] processing worksheet: CDIAK 1160-1
# 2026-02-11 15:49:55,449 [INFO] processing worksheet: fund 1161
# 2026-02-11 15:49:55,450 [INFO] processing worksheet: CDIAK 1161-1
# 2026-02-11 15:49:55,451 [INFO] processing worksheet: fund 1162
# 2026-02-11 15:49:55,452 [INFO] processing worksheet: CDIAK 1162-1c (old #s)
# 2026-02-11 15:49:55,453 [INFO] processing worksheet: CDIAK 1162-1 (new #s)
# 2026-02-11 15:49:55,455 [INFO] processing worksheet: fund 1163
# 2026-02-11 15:49:55,455 [INFO] processing worksheet: CDIAK 1163-1
# 2026-02-11 15:49:55,456 [INFO] processing worksheet: fond 1164
# 2026-02-11 15:49:55,456 [INFO] processing worksheet: CDIAK 1164-1
# 2026-02-11 15:49:55,462 [INFO] processing worksheet: CDIAK 1164-2
# 2026-02-11 15:49:55,484 [INFO] processing worksheet: fund 1165
# 2026-02-11 15:49:55,485 [INFO] processing worksheet: CDIAK 1165-1
# 2026-02-11 15:49:55,486 [INFO] processing worksheet: fund 1166
# 2026-02-11 15:49:55,487 [INFO] processing worksheet: CDIAK 1166-1
# 2026-02-11 15:49:55,489 [INFO] processing worksheet: fund 1167
# 2026-02-11 15:49:55,489 [INFO] processing worksheet: CDIAK 1167-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import_spreadsheet(file4)
#
# File ~/code/birddog/birddog/database_importer.py:302, in import_spreadsheet(sw_filepath)
#     300 db = Database()
#     301 workbook = load_workbook(sw_filepath)
# --> 302 page_data = process_worksheets(workbook)
#     304 doc_only_fields_all_caps = {
#     305     "doc_type",
#     306     "content_code",
#     307     "process_code",
#     308 }
#     309 doc_only_fields = doc_only_fields_all_caps | {
#     310     "pages_processed",
#     311     "processor",
#     312 }
#
# File ~/code/birddog/birddog/database_importer.py:288, in process_worksheets(worksheets, page_table)
#     286 _logger.info(f"processing worksheet: {sheet.title}")
#     287 if get_cell_value(sheet["H1"]):
# --> 288     page_table = process_opus_sheet(sheet, page_table)
#     289 elif get_cell_value(sheet["G1"]):
#     290     page_table = process_fond_sheet(sheet, page_table)
#
# File ~/code/birddog/birddog/database_importer.py:230, in process_opus_sheet(ws, page_table)
#     218     return page_table
#     220 source_type = get_cell_value(ws["C1"])
#     221 add_page({
#     222     "title": parent_title,
#     223     "label": page_label(parent_title), # get_cell_value(ws["H1"]),
#     224     "level": "opus",
#     225     "description": get_cell_value(ws["A2"]),
#     226     "availability": "linked",
#     227     "change_date": get_cell_value(ws["L1"]),
#     228     "timestamp": get_cell_value(ws["O1"]),
#     229     "doc_links": get_cell_value(ws["B4"]),
# --> 230     "parent": parent_title_no_ns(parent_title),
#     231     "source_type": source_type,
#     232     "wiki_link": get_cell_link(ws["D3"]),
#     233 }, page_table)
#     235 #there are sometimes columns inserted between "process" and "Comments",
#     236 #so we need to find the exact position of the latter one
#     237 hdr_row = 6
#
# File ~/code/birddog/birddog/database_importer.py:39, in parent_title_no_ns(title)
#      38 def parent_title_no_ns(title):
# ---> 39     result = parent_title(title)
#      40     if not result:
#      41         return None
#
# File ~/code/birddog/birddog/wiki.py:118, in parent_title(title)
#     116 title_split = title.split("/")
#     117 if title_split[0] not in ARCHIVES_BY_ROOT:
# --> 118     raise ValueError(f"Unrecognized archive root: {title}")
#     119 if len(title_split) > 2:
#     120     return title.rsplit("/", 1)[0]
#
# ValueError: Unrecognized archive root: Архів:Архіви/ЦДІАК/1167/1 | error in sheet CDIAK 1167-1
