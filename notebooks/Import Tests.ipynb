# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.database_importer import (
    import_spreadsheet,
    process_dir,
)
# Out:
# 2026-05-30 21:37:08,303 [INFO] Using local nocodb api: http://localhost:8080
# 2026-05-30 21:37:08,446 [INFO] Translation is enabled. Using GCP translator
# 2026-05-30 21:37:08,447 [INFO] Using Google Cloud translation API
# 2026-05-30 21:37:08,447 [INFO] GoogleCloudTranslator using REST API

# %%
file1 = "var/WAT/DAHO (Kharkiv)/DAHO-R-wiki-20260126.xlsx"
file2 = "var/WAT/DAHO (Kharkiv)/DAHO-D-wiki-20260206.xlsx"
file3 = "var/WAT/DADO (Donetsk)/DADO-D-wiki-20251027.xlsx"
file4 = "var/WAT/CDIAK (UKR history)/CDIAK-wiki-20260206.xlsx"
file5 = "var/WAT/DAKO (Kyiv)/DAKO-R-wiki-20260204.xlsx"
file6 = "var/WAT/DASO (Sumy)/DASO-R-wiki-20260126.xlsx"
file7 = "var/WAT/GDA-MOD-wiki-20250818.xlsx"
file8 = "var/WAT/DAKO/DAKO-D-general-wiki-20260213.xlsx"
file9 = "var/DAVIO-P-wiki-20250808.xlsx"
files = (
    #"var/DAVIO-P-wiki-20250808.xlsx",
    #"var/DAVIO-R-wiki-20260505.xlsx",
    #"var/DAVIO-D-wiki+other-20260505-working.xlsx",
    "var/DAKIRO-D-wiki-20260504.xlsx",
    "var/DAKIRO-P-wiki-20251016.xlsx",
    "var/DAKIRO-R-wiki-20260428.xlsx",

)
files = (
    "var/WAT/DAOO (Odessa)/DAOO-archives-20250523.xlsx",
    "var/WAT/DAOO (Odessa)/DAOO-D-wiki-20260427.xlsx",
    "var/WAT/DAOO (Odessa)/DAOO-R-wiki-20260426.xlsx",
)
files = (
    "var/WAT/DACHKO (Cherkassy)/DACHKO-D-wiki-20260526.xlsx",
    "var/WAT/DACHKO (Cherkassy)/DACHKO-R-wiki-20260526b.xlsx",
)
files = (
    "var/WAT/KUIZA (Izmail city)/KUIZA-R-wiki-20260526.xlsx",
    "var/WAT/KUIZA (Izmail city)/KUIZA-D-wiki-20260526.xlsx",
)
files = (
    "var/WAT/DALO (Lviv)/DALO-D-wiki-20250430.xlsx",
    "var/WAT/DALO (Lviv)/DALO-P-wiki-20250929.xlsx",
    "var/WAT/DALO (Lviv)/DALO-R-wiki-20260412.xlsx",
)
files = (
    "var/WAT/DAZHO (Zhitomir)/DAZHO-D-wiki-20260526.xlsx",
    "var/WAT/DAZHO (Zhitomir)/DAZHO-R-wiki-20260522.xlsx",
    "var/WAT/DAZHO (Zhitomir)/DAZHO-P-wiki-20260517.xlsx",
)

# %%
for f in files:
    import_spreadsheet(f)
# Out:
# 2026-05-30 21:37:33,730 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   localhost:api                         20.00    46.32    39.00       0.00           24
# 2026-05-30 21:37:45,397 [INFO] processing worksheet: DAZHO D wiki fund list
# 2026-05-30 21:37:45,398 [WARNING] Sheet DAZHO D wiki fund list contains volumes
# 2026-05-30 21:37:45,400 [WARNING]  Link ['https://uk.wikisource.org/wiki/Архів:ДАЖО/50'] in cell 'B44', sheet 'DAZHO D wiki fund list' differs from the page url https://uk.wikisource.org/wiki/Архів:ДАЖО/53
# 2026-05-30 21:37:45,401 [WARNING]  Link ['https://uk.wikisource.org/wiki/Архів:ДАЖО/74'] in cell 'B65', sheet 'DAZHO D wiki fund list' differs from the page url https://uk.wikisource.org/wiki/Архів:ДАЖО/79
# ...

# %%
#import_spreadsheet(file2)

# %%
#import_spreadsheet(file1)

# %%
#import_spreadsheet(file3)

# %%
#import_spreadsheet(file4)

# %%
#import_spreadsheet(file5)

# %%
import_spreadsheet(file6)
