# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
import mwparserfromhell
import wikitextparser as wtp

from birddog.wiki import (
    ARCHIVE_BASE,
    WIKI_NAMESPACE,
    mw_read_page,
    _parse_wikitext_table,
    _read_wiki_text,
    _is_table,
    #_expand_link_target,
)
# Out:
# 2025-07-29 13:50:05,655 [INFO] Using Google Cloud translation API (credentials file:/Users/jbrandt/code/birddog/google-cloud-translate-key.json)

# %%
titles = [ 
    "Архів:ДАПО/Р-1186/1",
    "Архів:ДАПО/Р-9126/9",
    "Архів:ДАЧкО/687/1",
    "Архів:ДАКрО/23",
    "Архів:ДАЖО/1/74",
    "Архів:ДАПО/Р/1–1000",
    "Архів:ДАПО/978/1",
    "Архів:ДАК/312/1",
    "Архів:Лука_Мала",
    "Архів:ЦДІАК/1/1",
    "Архів:ДАХО/Д",
    "Архів:ЦДІАК/28",
    "Архів:ЦДІАК/28/1",
    "Архів:ДАЖО/1",
    "Архів:ДАК/Р-352",
    "Архів:Архівний відділ виконавчого комітету Кременчуцької міської ради/Р",
    "Архів:ДАЖО/Д",
    "Архів:ДАДнО/Р-6478/2", 
    "Архів:ДАЖО/752", 
    "Архів:ДАКрО/225/1/25", 
    "Архів:ДАКрО/225", 
    "Архів:ДАСО/Р", 
    "Архів:ДАХмО/К", 
    "Архів:ДАКрО/225/1/144а", 
    "Архів:ДАПО/Р",
    "Архів:ДАХмО/Р-6193",
    "Архів:ДАКрО/П-5907/2Р",
    "Архів:ДАОО/Р-8085/1",
    "Архів:ДАКрО/225/1",
    "Архів:ДАПО/1072/1/1",
    "Архів:ДАПО/978/1/135",
    "Архів:ДАПО/978",
    ]

# %%
def process_title(title):
    wikitext, revid, title = _read_wiki_text(title)
    wikicode = mwparserfromhell.parse(wikitext)

    # Table data
    tables = [t for t in wikicode.filter_tags() if _is_table(t)]
    header = []
    children = []
    all_page_links = set()

    if tables:
        table_code = tables[0].contents # assume first table
        #return table_code
        header, children = _parse_wikitext_table(table_code)
        #return header

    print(f"------ {title} ({len(children)} rows)")
    print(f"{ARCHIVE_BASE}/wiki/{WIKI_NAMESPACE}:{title.replace(' ', '_')}")
    print("header:", header)
    for i, child in enumerate(children[:5]):
        print(f"    child[{i}]: {child}")

# %%
def process_title_2(title):
    page = mw_read_page(title)
    print(f"------ {title} -----")
    print(f"{ARCHIVE_BASE}/wiki/{title.replace(' ', '_')}")
    for table in page["tables"]:
        print(" ==== name:", table["name"])
        print("      header:", table["header"])
        print("      num children:", len(table["children"]))
        #for i, child in enumerate(table["children"][:5]):
        #    print(f"     child[{i}]: {child}")
    print(" ==== notes:")
    for key, val in page["notes"].items():
        print(f"     {key}: {val}")
    print(" ==== other_links:")
    for key, val in page["other_links"].items():
        print(f"     {key}: {val}")

# %%
process_title_2(titles[0])
# Out:
# 2025-07-29 13:57:54,689 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# ------ Архів:ДАПО/Р-1186/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/Р-1186/1
#  ==== name: Table 1
#       header: [{'uk': 'Номер справи'}, {'uk': 'Назва (сучасна українська мова)'}, {'uk': 'Назва (оригінал)'}, {'uk': 'Крайні дати'}, {'uk': 'Кількість аркушів'}]
#       num children: 32
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []

# %%
process_title_2("Архів:ІР_НБУВ")
# Out:
# ------ Архів:ІР_НБУВ -----
# https://uk.wikisource.org/wiki/Архів:ІР_НБУВ
#  ==== name: Table 1
#       header: [{'uk': '№ фонду'}, {'uk': 'Назва фонду'}, {'uk': 'Крайні дати'}, {'uk': 'Справ'}]
#       num children: 86
#  ==== name: Table 2
#       header: [{'uk': '№ фонду'}, {'uk': 'Назва фонду'}, {'uk': 'Крайні дати'}, {'uk': 'Справ'}]
#       num children: 375
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['http://www.nbuv.gov.ua/node/1']
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Архіви України']
#      internal_links: []
#      external_links: ['https://irbis-nbuv.gov.ua/E_LIB/PDF/EIF0000078.pdf', 'https://irbis-nbuv.gov.ua/E_LIB/PDF/EIF0000066.pdf', 'https://irbis-nbuv.gov.ua/E_LIB/PDF/00000073.pdf', 'http://irbis-nbuv.gov.ua/E_LIB/PDF/00000073.pdf', 'https://irbis-nbuv.gov.ua/cgi-bin/irbis_arch/cgiirbis_64.exe?S21CNR=20&S21STN=1&S21REF=2&C21COM=S&I21DBN=FOND&P21DBN=FOND&S21All=%3C.%3ETZ=FOND%3C.%3E&S21FMT=full_all&Z21ID=&S21COLORTERMS=0&S21SRW=PIB&S21SRD=UP']

# %%
for title in titles:
    process_title_2(title)
# Out:
# 2025-07-29 13:58:39,581 [INFO] fetch_url: 17 requests in last 60s → 0.28 req/s
# ------ Архів:ДАПО/Р-1186/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/Р-1186/1
#  ==== name: Table 1
#       header: [{'uk': 'Номер справи'}, {'uk': 'Назва (сучасна українська мова)'}, {'uk': 'Назва (оригінал)'}, {'uk': 'Крайні дати'}, {'uk': 'Кількість аркушів'}]
#       num children: 32
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
# ------ Архів:ДАПО/Р-9126/9 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/Р-9126/9
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'РАЦС'}, {'uk': 'Роки'}, {'uk': 'Сторінки'}]
#       num children: 141
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ДАПО_фонд_Р-9126_опис_9.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Глобинський район']
#      internal_links: []
#      external_links: []
# ------ Архів:ДАЧкО/687/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАЧкО/687/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Сторінки'}]
#       num children: 10
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ДАЧкО_фонд_687_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Звенигородський повіт']
#      internal_links: []
#      external_links: []
# ------ Архів:ДАКрО/23 -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/23
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні\xa0дати'}, {'uk': 'Справ'}]
#       num children: 1
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Новомиргород']
#      internal_links: ['Файл:FSMosaicTreeLogo-ea9718ee4daec6abe5ce7ac8cf6ff331.png', 'Файл:Миколаївський собор (Новомиргород).jpg']
#      external_links: []
# ------ Архів:ДАЖО/1/74 -----
# https://uk.wikisource.org/wiki/Архів:ДАЖО/1/74
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Повіт'}, {'uk': 'Роки'}, {'uk': 'Аркушів'}, {'uk': 'Посилання на FamilySearch'}]
#       num children: 416
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:Державний_архів_Житомирської_області._Каталог_метричних_книг._Том_1.pdf', 'https://commons.wikimedia.org/wiki/File:Державний_архів_Житомирської_області._Каталог_метричних_книг._Том_2.pdf', 'https://commons.wikimedia.org/wiki/file:ДАЖО_фонд_1_опис_74.pdf']
#      category_links: []
#      internal_links: []
#      external_links: ['https://zhytomyr.archives.gov.ua/?page_id=669']
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Волинська губернія']
#      internal_links: ['Файл:FSMosaicTreeLogo-ea9718ee4daec6abe5ce7ac8cf6ff331.png', 'Файл:Скит 001.jpg']
#      external_links: ['https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730970', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606959', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730983', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606900', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730969', 'https://www.familysearch.org/ru/records/images/search-results?imageGroupNumbers=116730978', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730982', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116494904', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606919', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116494871', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730962', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730985', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730980', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730997', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116730993', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116731001', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116731026', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606883', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606870', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116606875', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116456597', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116968504', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116968517', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116968518', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=116968522']
# ------ Архів:ДАПО/Р/1–1000 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/Р/1–1000
#  ==== name: Table 1
#       header: [{'uk': 'Фонд'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Описів'}, {'uk': 'Од.зб.'}]
#       num children: 167
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../../', '../1001–2000/']
#      external_links: []
# ------ Архів:ДАПО/978/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/978/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Аркуші'}, {'uk': 'Family Search', 'en': 'Family Search'}]
#       num children: 154
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:DAPO-978-1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149209', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149192', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149234', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149218', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149223', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149204', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160031', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160029', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149261', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149225', 'https://www.familysearch.org/records/images/beta/search-results?imageGroupNumbers=108149410', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149235', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149217', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149187', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149156', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149168', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160017', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160021', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149162', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160014', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160025', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160008', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160037', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160040', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149173', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149152', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108159984', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160010', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108160015', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149182', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149147', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149143', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108149142', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201614', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201553', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201619', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201610', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201604', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201625', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201564', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201616', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201621', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201785', 'https://www.familysearch.org/records/images/search-results?imageGroupNumbers=108201605', 'https://www. ...
# ------ Архів:ДАК/312/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАК/312/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Дата'}, {'uk': 'Аркушів'}, {'uk': 'Примітки'}]
#       num children: 34
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:ДАК_фонд_312,_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
# ------ Архів:Лука_Мала -----
# https://uk.wikisource.org/wiki/Архів:Лука_Мала
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні\xa0дати'}, {'uk': 'Аркуші'}]
#       num children: 1
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['Архіви', 'w:uk:Мала_Лука']
#      external_links: []
# 2025-07-29 13:58:49,677 [INFO] fetch_url: 59 requests in last 60s → 0.98 req/s
# ------ Архів:ЦДІАК/1/1 -----
# https://uk.wikisource.org/wiki/Архів:ЦДІАК/1/1
#  ==== name: Table 1
#       header: [{'uk': 'Номер справи'}, {'uk': 'Назва справи'}, {'uk': 'Крайні дати'}, {'uk': 'Кількість аркушів'}]
#       num children: 2
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ЦДІАК_фонд_1_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: ['https://cdiak.archives.gov.ua/spysok_fondiv/0001/0001/']
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Річ Посполита']
#      internal_links: ['Файл:Žygimont Aŭgust, Pahonia. Жыгімонт Аўгуст, Пагоня crop.png']
#      external_links: []
# ------ Архів:ДАХО/Д -----
# https://uk.wikisource.org/wiki/Архів:ДАХО/Д
#  ==== name: Table 1
#       header: [{'uk': 'Номер'}, {'uk': 'Назва фонду'}, {'uk': 'Крайні дати'}, {'uk': 'Од. зб.'}, {'uk': 'Примітки'}]
#       num children: 1036
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['http://archives.kh.gov.ua']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../', '../Р/', 'Архів:ЦДІАК/1627', 'Архів:ЦДІАК/969', 'Архів:ЦДІАК/1676', 'Архів:ЦДІАК/1191', 'Архів:ЦДІАК/336', 'Архів:ДАСО/637', 'Архів:ДАПО/540', 'Архів:ДАЖО/178', 'Архів:ДАСО/775']
#      external_links: []
# ------ Архів:ЦДІАК/28 -----
# https://uk.wikisource.org/wiki/Архів:ЦДІАК/28
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація опису'}, {'uk': 'Крайні дати'}, {'uk': 'Кількість справ'}]
#       num children: 1
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['http://cdiak.archives.gov.ua/spysok_fondiv/0028/']
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Волинське воєводство']
#      internal_links: []
#      external_links: []
# ------ Архів:ЦДІАК/28/1 -----
# https://uk.wikisource.org/wiki/Архів:ЦДІАК/28/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва справи'}, {'uk': 'Крайні дати'}, {'uk': 'Кількість аркушів'}, {'uk': 'Копія справи на FS'}]
#       num children: 65
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ЦДІАК_фонд_28_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: ['https://cdiak.archives.gov.ua/spysok_fondiv/0028/0001/']
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Волинське воєводство']
#      internal_links: []
#      external_links: ['https://www.familysearch.org/ark:/61903/3:1:3QHK-D7DJ-5G3J?view=explore&groupId=TH-7784-146336-7814-54&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHN-B7DF-Z9PS-P?view=explore&groupId=TH-7715-146267-1220-40&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-X7DJ-T997?view=explore&groupId=TH-7782-146334-13032-52&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-W7DF-VN9C?view=explore&groupId=TH-7717-146269-3945-60&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-77DF-J7SM?view=explore&groupId=TH-7713-146265-15113-15&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-F7DJ-YNCC?view=explore&groupId=TH-7787-146339-4253-20&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-N7DJ-BNYJ?view=explore&groupId=TH-7787-146339-7346-32&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-M7DF-DS5L-C?view=explore&groupId=TH-7721-146273-5274-45&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-W7DF-VPK3?view=explore&groupId=TH-7710-146262-63010-25&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-C7DF-LWMH?view=explore&groupId=TH-7719-146271-5406-89&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHN-B7DF-Z9MW-G?view=explore&groupId=TH-7711-146263-5602-82&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-H7DF-2972?view=explore&groupId=TH-7718-146270-1063-49&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-M7DF-D3R2-Z?view=explore&groupId=TH-7726-146278-8665-73&grid=on&lang=en', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-87DF-PZW2?view=explore&groupId=TH-7710-146262-80085-48&grid=on&lang=en', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-67DF-RWX?view=explore&groupId=TH-7720-146272-11987-31&grid=on&lang=en', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-27DV-SSWD?view=explore&groupId=TH-7788-146340-14480-28&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-G7DV-QHQ7?view=explore&groupId=TH-7792-146344-7153-79&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-P7DV-7WT5?view=explore&groupId=TH-7791-146343-16585-50&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-K7DV-97WK?view=explore&groupId=TH-7789-146341-4173-34&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-X7DF-T7WR?view=explore&groupId=TH-7710-146262-90894-42&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-K7DN-9SB2?view=explore&groupId=TH-7729-146281-2608-96&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-V7DV-MV37?view=explore&groupId=TH-7789-146341-8669-61&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-G7DN-Q925?view=explore&groupId=TH-7730-146282-9812-47&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHK-K7DV-9V9R?view=explore&groupId=TH-7790-146342-11806-47&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHV-47DN-KGJB?view=explore&groupId=TH-7747-146299-19732-63&grid=on&lang=en', 'https://www.familysearch.org/ark:/61903/3:1:3QHJ-Z7DF-GJFR?view=explore&groupId=TH-7724-146276-61-49&grid=on&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHV-47DN-K93V-V?view=explore&groupId=TH-7748-146300-29909-41&lang=uk', 'https://www.familysearch.org/ark:/61903/3:1:3QHV-77DN-JF9P?view=explore&groupId=TH-7747-146299-2347-53&grid=on&lang=en']
# ------ Архів:ДАЖО/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАЖО/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні дати'}, {'uk': 'Справ'}]
#       num children: 91
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Волинська губернія']
#      internal_links: ['Файл:FSMosaicTreeLogo-ea9718ee4daec6abe5ce7ac8cf6ff331.png', 'Файл:Скит 001.jpg', 'Архів:ДАВоО/35', 'Архів:ДАРО/485']
#      external_links: []
# ------ Архів:ДАК/Р-352 -----
# https://uk.wikisource.org/wiki/Архів:ДАК/Р-352
#  ==== name: Table 1
#       header: [{'uk': 'Опис'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Справ'}]
#       num children: 44
#  ==== notes:
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Київ']
#      internal_links: []
#      external_links: []
# ------ Архів:Архівний відділ виконавчого комітету Кременчуцької міської ради/Р -----
# https://uk.wikisource.org/wiki/Архів:Архівний_відділ_виконавчого_комітету_Кременчуцької_міської_ради/Р
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва фонду'}, {'uk': 'Крайні дати'}, {'uk': 'Справ'}]
#       num children: 105
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['https://kremen.gov.ua/?view=single-str&dep-id=44']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../']
#      external_links: []
# 2025-07-29 13:58:59,874 [INFO] fetch_url: 93 requests in last 60s → 1.55 req/s
# ------ Архів:ДАЖО/Д -----
# https://uk.wikisource.org/wiki/Архів:ДАЖО/Д
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва фонду'}, {'uk': 'Крайні дати'}, {'uk': 'Справ'}]
#       num children: 475
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['https://zhytomyr.archives.gov.ua/?page_id=276']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../', '../Р']
#      external_links: []
# ------ Архів:ДАДнО/Р-6478/2 -----
# https://uk.wikisource.org/wiki/Архів:ДАДнО/Р-6478/2
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Справ'}]
#       num children: 2
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Дніпро']
#      internal_links: []
#      external_links: []
# ------ Архів:ДАЖО/752 -----
# https://uk.wikisource.org/wiki/Архів:ДАЖО/752
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні\xa0дати'}, {'uk': 'Справ'}]
#       num children: 2
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
# ------ Архів:ДАКрО/225/1/25 -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/225/1/25
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:ДАКрО_225-1-25_Про_здійснення_закладної_кріпості_Х.Г.Г.Ґрітберґа_та_Л.Н.Луценка._(1918).pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кропивницький']
#      internal_links: ['File:ДАКрО 225-1-25 Про здійснення закладної кріпості Х.Г.Г.Ґрітберґа та Л.Н.Луценка. (1918).pdf']
#      external_links: ['https://www.familysearch.org/records/images/search-results?imageGroupNumbers=110808887']
# ------ Архів:ДАКрО/225 -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/225
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні\xa0дати'}, {'uk': 'Справ'}]
#       num children: 1
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
# ------ Архів:ДАСО/Р -----
# https://uk.wikisource.org/wiki/Архів:ДАСО/Р
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['https://daso.archives.gov.ua/wp-content/home/info/nashi-vydannya/13_reestr_after1917.pdf']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../', '../Д/', '../П/', '/1–1000/', '/1001–2000/', '/2001–3000/', '/3001–4000/', '/4001–5000/', '/5001–6000/', '/6001–7000/', '/7001–8000/']
#      external_links: []
# ------ Архів:ДАХмО/К -----
# https://uk.wikisource.org/wiki/Архів:ДАХмО/К
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Алея_Трудової_Слави.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_охорони_здоровья_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._ВДНХ_СРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_промисловості_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Герой_Радянського_Союзу.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_професійно-технічної_освіти_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Герой_Соціалістичної_Праці.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_сільського_господарства_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Грамота_і_почесна_Грамота_Пр._ВР_УРСР_колективам.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_сфери_послуг_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Грамота_Президії_ВР_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_тогівлі_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_агроном_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_працівник_транспорту_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_артист_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_раціоналізатор_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_будівельник_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_художник_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_винахідник_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_шляховик_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_вчитель_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_юрист_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_діяч_науки_і_техніки_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._звання_Підприємство_високої_якості_продукції.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_економіст_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Кавалер_Ордена_Слави.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_енергетик_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Медаль_за_бойові_заслуги_та_відвагу.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_журналіст_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Медаль_Материнства.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_зоотехнік_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Народний_артист_Української_РСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_лікар_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Нові_назви_в_честь_60_-_річчя_СРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_лісовод_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Орден_Трудовой_Славы.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_майстер_народної_творчості_України.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Перехідні_Червоні_прапори_обкому_Компартії_України_та_облвиконкому.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Заслужений_машинобудівник_УРСР.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._Перехідні_Червоні_прапори_Ради_Міністрів_УРСР,_Укр._республіканської_ради_профспілок.pdf', 'https://commons.wikimedia.org/wiki/File:ДАХмО_Картотека._ ...
#      category_links: []
#      internal_links: ['../']
#      external_links: []
# ------ Архів:ДАКрО/225/1/144а -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/225/1/144а
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:ДАКрО_225-1-144а_Про_здійснення_розподільного_акта_Бондарев_–_Кармогін,_Очєсальська_та_Дербякова._(1918).pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кропивницький']
#      internal_links: ['File:ДАКрО 225-1-144а Про здійснення розподільного акта Бондарев – Кармогін, Очєсальська та Дербякова. (1918).pdf']
#      external_links: ['https://www.familysearch.org/records/images/search-results?imageGroupNumbers=110638701']
# ------ Архів:ДАПО/Р -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/Р
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: ['http://poltava.archives.gov.ua/']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../', '../Д/', '../П/', '/1–1000/', '/1001–2000/', '/2001–3000/', '/3001–4000/', '/4001–5000/', '/5001–6000/', '/6001–7000/', '/7001–8000/', '/8001–9000/', '/9001–10000/']
#      external_links: []
# ------ Архів:ДАХмО/Р-6193 -----
# https://uk.wikisource.org/wiki/Архів:ДАХмО/Р-6193
#  ==== name: Table 1
#       header: [{'uk': 'Опис'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Справ'}]
#       num children: 22
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: ['Файл:FSMosaicTreeLogo-ea9718ee4daec6abe5ce7ac8cf6ff331.png']
#      external_links: ['https://www.familysearch.org/records/images/search-results?keyword=%22%D0%A0-6193%22']
#  ==== other_links:
#      commons_links: []
#      category_links: []
#      internal_links: ['../']
#      external_links: []
# ------ Архів:ДАКрО/П-5907/2Р -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/П-5907/2Р
#  ==== name: Table 1
#       header: [{'uk': 'Том'}, {'uk': 'Справи'}]
#       num children: 23
#  ==== notes:
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кіровоградська область']
#      internal_links: []
#      external_links: []
# 2025-07-29 13:59:10,091 [INFO] fetch_url: 125 requests in last 60s → 2.08 req/s
# ------ Архів:ДАОО/Р-8085/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАОО/Р-8085/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'РАЦС'}, {'uk': 'Роки'}, {'uk': 'Сторінки'}]
#       num children: 2112
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ДАОО_фонд_Р-8085_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Одеса']
#      internal_links: []
#      external_links: []
# ------ Архів:ДАКрО/225/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАКрО/225/1
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Назва'}, {'uk': 'Роки'}, {'uk': 'Сторінки'}]
#       num children: 343
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/file:ДАКрО_фонд_225_опис_1.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кропивницький']
#      internal_links: []
#      external_links: []
# 2025-07-29 13:59:20,200 [INFO] fetch_url: 169 requests in last 60s → 2.82 req/s
# ------ Архів:ДАПО/1072/1/1 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/1072/1/1
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:ДАПО_Фонд_1072,_опис_1,_справа_1._1900-1906_роки._Метрична_книга_синагоги_Пирятина._Народження.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Пирятин']
#      internal_links: ['File:ДАПО Фонд 1072, опис 1, справа 1. 1900-1906 роки. Метрична книга синагоги Пирятина. Народження.pdf', 'Пирятин']
#      external_links: []
# ------ Архів:ДАПО/978/1/135 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/978/1/135
#  ==== notes:
#      commons_links: ['https://commons.wikimedia.org/wiki/File:DAPO-F-978-1-135.pdf']
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кременчук']
#      internal_links: ['File:DAPO-F-978-1-135.pdf', 'Кременчук']
#      external_links: []
# ------ Архів:ДАПО/978 -----
# https://uk.wikisource.org/wiki/Архів:ДАПО/978
#  ==== name: Table 1
#       header: [{'uk': '№'}, {'uk': 'Анотація'}, {'uk': 'Крайні\xa0дати'}, {'uk': 'Справ'}]
#       num children: 1
#  ==== notes:
#      commons_links: []
#      category_links: []
#      internal_links: []
#      external_links: []
#  ==== other_links:
#      commons_links: []
#      category_links: ['Категорія:Кременчук']
#      internal_links: []
#      external_links: []

# %%
pg = mw_read_page("Архів:АВПРИ")
# Out:
# 2025-07-29 13:53:35,658 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s

# %%
pg["other_links"]
# Out:
# {'commons_links': [],
#  'category_links': [],
#  'internal_links': ['Архіви'],
#  'external_links': []}

# %%
pg["notes"]
# Out:
# {'commons_links': [],
#  'category_links': [],
#  'internal_links': [],
#  'external_links': ['https://drive.google.com/file/d/1VjZKRxLtBERLhl-vJESnjf2ci0PZ-XgG/view?usp=drivesdk']}

# %%
pg = mw_read_page("Архів:ДАРО/31/20")
# Out:
# 2025-07-29 13:51:31,888 [INFO] fetch_url: 4 requests in last 60s → 0.07 req/s

# %%
pg["doc_link"]
# Out:
# 'https://commons.wikimedia.org/wiki/file:ДАРО_фонд_31_опис_20.pdf'

# %%
process_title(titles[0])

# %%
for title in titles:
    process_title(title)

# %%
for i, title in enumerate(titles):
    print("------", i)
    process_title_2(title)

# %%
archive = A
