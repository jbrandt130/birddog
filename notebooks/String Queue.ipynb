# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.store import get_string_queue_store

# %%
qs = get_string_queue_store()

# %%
qn = "test q"

# %%
print(qs.peek(qn, 5))

# %%
qs.append(qn, [f"string-{i}" for i in range(10)])

# %%
print(qs.peek(qn, 5))

# %%
qs.pop(qn, 3)

# %%
print(qs.peek(qn, 5))

# %%
qs.append(qn, [f"string-{i+10}" for i in range(100)])

# %%
print(qs.peek(qn, 15))

# %%
qs.length(qn)

# %%
qs.peek(qn, 1000)

# %%
qn = "pending_titles"

# %%
qs.peek(qn, 10)
# Out:
# ['Архів:ДАХмО/17/1/191',
#  'Архів:ДАХмО/17/1/192',
#  'Архів:ДАХмО/17/1/193',
#  'Архів:ДАХмО/17/1/194',
#  'Архів:ДАХмО/17/1/195',
#  'Архів:ДАХмО/17/1/196',
#  'Архів:ДАХмО/17/1/197',
#  'Архів:ДАХмО/17/1/198',
#  'Архів:ДАХмО/17/1/199',
#  'Архів:ДАХмО/17/1/2']

# %%
qs.length(qn)
# Out:
# 54340
