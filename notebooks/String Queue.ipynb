# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.store import get_string_queue_store

# %%
qs = get_string_queue_store()

# %%
qn = "test q"

# %%
print(qs.peek(qn, 5))
# Out:
# []

# %%
qs.append(qn, [f"string-{i}" for i in range(10)])

# %%
print(qs.peek(qn, 5))
# Out:
# ['string-0', 'string-1', 'string-2', 'string-3', 'string-4']

# %%
qs.claim(qn, 3, 5000, "id1")
# Out:
# [ClaimedItem(receipt='2', value='string-0'),
#  ClaimedItem(receipt='3', value='string-1'),
#  ClaimedItem(receipt='4', value='string-2')]

# %%
print(qs.peek(qn, 5))
# Out:
# ['string-0', 'string-1', 'string-2', 'string-3', 'string-4']

# %%
qs.append(qn, [f"string-{i+10}" for i in range(100)])

# %%
print(qs.peek(qn, 15))
# Out:
# ['string-0', 'string-1', 'string-2', 'string-3', 'string-4', 'string-5', 'string-6', 'string-7', 'string-8', 'string-9', 'string-10', 'string-11', 'string-12', 'string-13', 'string-14']

# %%
qs.length(qn)
# Out:
# 110

# %%
len(qs.peek(qn, 1000))
# Out:
# 110

# %%
qn = "pending_titles"

# %%
qs.peek(qn, 10)

# %%
qs.length(qn)
