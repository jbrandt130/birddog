# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.store import DynamoDBStringQueue, SQLiteStringQueue

# %%
q = DynamoDBStringQueue(table_name="bd_task_queue")
#q = SQLiteStringQueue(table_name="bd_task_queue")

# %%
q.dump("TranslationManager:pending")
# Out:
# [{'queue_name': 'TranslationManager:pending',
#   'ts': Decimal('1769903764.7537269'),
#   'value': None,
#   'value_type': 'NoneType',
#   'value_len': None,
#   'lease_until_ms': Decimal('1769903889405'),
#   'lease_owner': 'TranslationManager:01KGB7M8FQ442SK6AM1PDEGXY2',
#   'claimed_at_ms': Decimal('1769903769405')},
#  {'queue_name': 'TranslationManager:pending',
#   'ts': Decimal('1769903764.7537329'),
#   'value': None,
#   'value_type': 'NoneType',
#   'value_len': None,
#   'lease_until_ms': Decimal('1769903894395'),
#   'lease_owner': 'TranslationManager:01KGB7M8FQ442SK6AM1PDEGXY2',
#   'claimed_at_ms': Decimal('1769903774395')},
#  {'queue_name': 'TranslationManager:pending',
#   'ts': Decimal('1769903764.7537409'),
#   'value': None,
#   'value_type': 'NoneType',
#   'value_len': None,
#   'lease_until_ms': Decimal('1769903901355'),
#   'lease_owner': 'TranslationManager:01KGB7M8FQ442SK6AM1PDEGXY2',
#   'claimed_at_ms': Decimal('1769903781355')},
# ...
