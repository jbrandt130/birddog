# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
#import os
#os.environ["BIRDDOG_USE_LOCAL_CACHE"] = ""

# %%
import json
from birddog.store import KeyValueStore, DynamoDBKeyValueStore
from birddog.cache import load_cached_object
from birddog.user import _watcher_cache_path
# Out:
# 2026-02-20 09:26:58,189 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.
# 2026-02-20 09:26:58,423 [INFO] Translation is enabled. Using GCP translator
# 2026-02-20 09:26:58,425 [INFO] Using Google Cloud translation API
# 2026-02-20 09:26:58,425 [INFO] GoogleCloudTranslator using REST API
# 2026-02-20 09:26:58,782 [INFO] Using aws nocodb api: http://nocodb-env.eba-xhmfyydr.us-east-2.elasticbeanstalk.com

# %%
#store = DynamoDBKeyValueStore()
store = KeyValueStore()

# %%
email = "jberland@jewishgen.org"
ns = f"wl:{email}"
archive = "DAVIO"
subarchive = "D"
key = f"{archive}-{subarchive}"
path = _watcher_cache_path(email, archive, subarchive)

# %%
email = "jon4@test.com"
ns = f"wl:{email}"
archive = "DAVIO"
subarchive = "D"
key = f"{archive}-{subarchive}"
path = _watcher_cache_path(email, archive, subarchive)

# %%
path
# Out:
# 'watchers/jon4@test.com/DAVIO-D.json'

# %%
wl = json.loads(store.get(ns, key))

# %%
wl
# Out:
# {'cutoff_date': '2025,07,01', 'last_checked_date': '2026,02,20,09:24'}

# %%
watcher = load_cached_object(path)

# %%
unresolved = watcher["unresolved"]
resolved = watcher["resolved"]

# %%
for k in unresolved:
    if k.startswith("DAVIO,D,904,10"):
        print(k, unresolved[k])

# %%
for k in resolved:
    if k.startswith("DAVIO,D,904,10"):
        print(k, resolved[k])
# Out:
# DAVIO,D,904,10, [{'modified': '2026,01,31,18:18', 'last_resolved': '2026,02,20,09:30', 'title': 'Архів:ДАВіО/904/10', 'user': 'Alexkrakovsky'}]
