# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.translate import TranslationManager, get_translation_items, apply_translation
from birddog.runtime import Runtime
# Out:
# 2026-01-30 18:11:25,453 [INFO] Using DDB task manager store
# 2026-01-30 18:11:25,454 [INFO] Translation is enabled. Using GCP translator
# 2026-01-30 18:11:25,455 [INFO] Using Google Cloud translation API
# 2026-01-30 18:11:25,455 [INFO] GoogleCloudTranslator using REST API
# 2026-01-30 18:11:25,463 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.
# 2026-01-30 18:11:25,894 [INFO] Using aws nocodb api: http://nocodb-env.eba-xhmfyydr.us-east-2.elasticbeanstalk.com

# %%
runtime = Runtime()
# Out:
# 2026-01-30 18:11:25,897 [INFO] PageUpdateManager.init(): detect_environment==local
# 2026-01-30 18:11:26,118 [INFO] Found credentials in environment variables.
# 2026-01-30 18:11:27,333 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# 2026-01-30 18:11:28,043 [INFO] KillSwitch: loading thresholds from resources/kill_thresholds.json
# 2026-01-30 18:11:28,046 [INFO] Runtime: truncating log history before 2026-01-16 01:11:28.046358+00:00

# %%
mgr = runtime._translation_manager

# %%
mgr._any_pending()

# %%
mgr._in_process_id

# %%
subtask = mgr._claim_next()
# Out:
# 2026-01-30 18:19:19,943 [INFO] _claim_next: 01KG8KDPBAT88ZTKSTM1P2K1GB.1 (receipt=1769815333.2904811, attempt=1)

# %%
subtask
# Out:
# {'task_id': '01KG8KDPBAT88ZTKSTM1P2K1GB',
#  'index': 1,
#  'payload': ['Переяславський повітовий революційний комітет, м.\xa0Переяслав Полтавської губернії',
#   'Сквирський повітовий революційний комітет, м.\xa0Сквира Київської губернії',
#   'Чорнобильський повітовий революційний комітет, м.\xa0Чорнобиль Київської губернії',
#   'Київське окружне відділення української асоціації робітників-винахідників, м.\xa0Київ',
#   'Трипільський волосний революційний комітет, с.\xa0Трипілля Київського повіту Київської губернії',
#   'Абрамівська сільська рада робітничих, селянських і червоноармійських депутатів, с.\xa0Абрамівка Димерського району Київської губернії',
#   'Андріївська сільська рада робітничих, селянських і червоноармійських депутатів, с.\xa0Андріївка Макарівського району Київської області',
#   'Виконавчий комітет Бородянської сільської ради депутатів трудящих, с.\xa0Бородянка Бородянського району Київської області',
#   '1920–1930, 1944–1958',
#   'Ірпінська сільськогосподарська артіль «Незаможник», сел. Ірпінь Київського району Київського округу'],
#  '_receipt': '1769815333.2904811',
#  'attempt': 1}

# %%
def _check_finished(self, subtask):
    try:
        self._key_value_store.get(self._completed_id(subtask["task_id"]), str(subtask["index"]))
        return True
    except KeyError:
        pass
    try:
        self._key_value_store.get(self._failed_id(subtask["task_id"]), str(subtask["index"]))
        return True
    except KeyError:
        return False

# %%
_check_finished(mgr, subtask)
# Out:
# True

# %%
mgr._ack_subtask(subtask)
# Out:
# 2026-01-30 18:19:26,467 [INFO] _ack_subtask: 01KG8KDPBAT88ZTKSTM1P2K1GB.1

# %%
mgr._key_value_store.count(mgr._in_process_id)

# %%
mgr._queue_store.peek(mgr._pending_id, 1)

# %%
mgr._any_pending()

# %%
page = runtime.lookup_by_address("DAZHO", "D", "1", "1")

# %%
page.title

# %%
page.needs_translation

# %%
mgr.translate(page)

# %%
mgr.translate(runtime.lookup_by_address("DAZHO", "D", "1"))

# %%
mgr.translate(runtime.lookup_by_address("DAZHO", "D"))

# %%
import time
while mgr.is_active():
    for task in mgr.active_tasks():
        print(f"{task['name']}: {task['completed']}/{task['length']}")
    time.sleep(1)

# %%
mgr.is_active()

# %%
page.title

# %%
from birddog.wiki import mw_read_page

# %%
pg = mw_read_page(page.title)

# %%
pg

# %%
from birddog.translate import translation, translate_structure, get_translation_items, apply_translation

# %%
get_translation_items(pg)

# %%
translation(get_translation_items(pg))

# %%
translate_structure(pg)

# %%
pg
