# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.core import Archive, lookup_page_by_title, PageLRU
from birddog.excel import export_page
lru = PageLRU()
# Out:
# 2025-06-22 12:37:52,800 [INFO] Using Google Cloud translation API (credentials file:/Users/jbrandt/code/birddog/google-cloud-translate-key.json)
# 2025-06-22 12:37:52,804 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.

# %%
titles = [ 
    "Архів:ДАЖО/1/1",
    "Архів:ДАК/312/1",
    "Архів:ДАЖО/1/74",
    "Архів:Лука_Мала",
    "Архів:ЦДІАК/1/1",
    "Архів:ДАХО/Д",
#    "Архів:ДАПО/Р/1–1000",
    "Архів:ЦДІАК/28",
    "Архів:ЦДІАК/28/1",
    "Архів:ДАЖО/1",
    "Архів:ДАК/Р-352",
    "Архів:Архівний відділ виконавчого комітету Кременчуцької міської ради/Р",
    "Архів:ДАЖО/Д",
    "Архів:ДАДнО/Р-6478/2", 
    "Архів:ДАЖО/752", 
    "Архів:ДАКрО/225/1/25", 
    "Архів:ДАКрО/225", 
    "Архів:ДАСО/Р", 
    "Архів:ДАХмО/К", 
    "Архів:ДАКрО/225/1/144а", 
    "Архів:ДАПО/978/1",
    "Архів:ДАПО/Р",
    "Архів:ДАХмО/Р-6193",
    "Архів:ДАКрО/П-5907/2Р",
    "Архів:ДАОО/Р-8085/1",
    "Архів:ДАКрО/225/1",
    "Архів:ДАПО/1072/1/1",
    "Архів:ДАПО/978/1/135",
    "Архів:ДАПО/978",
    ]

# %%
#for title in titles:
#    print(lookup_page_by_title(title))

# %%
def report_links(links):
    for key, value in links.items():
        if value:
            print(f"  {key}: {value}")

# %%
def process_title(title):
    address = lookup_page_by_title(title)
    print("=====", title, address)
    if address:
        page = lru.lookup(*address)
        print(page.report)
        print("link:", page.url)
        print("dates:", page._page["dates"])
        print("doc url:", page.doc_url)
        print("other links:")
        report_links(page._page["other_links"])
        print("notes:")
        report_links(page._page["notes"])

# %%
process_title(titles[0])
# Out:
# 2025-06-22 12:37:56,726 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# ===== Архів:ДАЖО/1/1 ('DAZHO', 'D', '1', '1', '')
# opus,DAZHO-D/1/1,2025,04,29,19:30
# link: https://uk.wikisource.org/wiki/Архів:ДАЖО/1/1
# dates: {'uk': '1790–1799', 'en': '1790–1799'}
# doc url: https://commons.wikimedia.org/wiki/File:ДАЖО_Фонд_1_Опис_1.pdf
# other links:
#   category_links: ['Категорія:Волинська губернія']
# notes:
#   commons_links: ['https://commons.wikimedia.org/wiki/File:ДАЖО_Фонд_1_Опис_1.pdf']

# %%
for title in titles:
    process_title(title)

# %%
pg = lru.lookup(*lookup_page_by_title(titles[0]))

# %%
pg.children[0]
# Out:
# [{'text': {'uk': '1', 'en': '1'},
#   'link': '/wiki/Архів:ДАЖО/1/1/1',
#   'exists': False},
#  {'text': {'uk': 'О браках в родствах духовных'}, 'link': None},
#  {'text': {'uk': '1790', 'en': '1790'}, 'link': None},
#  {'text': {'uk': '327', 'en': '327'}, 'link': None},
#  {'text': {'uk': '', 'en': ''}, 'link': None}]

# %%
from birddog.utility import link_status

# %%
link_status(pg.children[0][0])
# Out:
# 'linked'
