# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
import json

# %%
with open("var/jberland@jewishgen.org.json", "r") as f:
    user = json.loads(f.read())

# %%
user
# Out:
# {'name': 'Juliana',
#  'password': 'scrypt:32768:8:1$JpTEmboMqYzn5SKN$4f2666e12bee81fc7a73417062029c2eb4e536006c5b0881b804fcc517538e361725e2cc5653a29e3a7cd0384dbba0cb9fca7bc9eb0ff1888fa4e382eaa57340',
#  'watchlist': {'DAHMO-K': {'last_checked_date': '2025,12,02,11:51',
#    'cutoff_date': '2019,01,01'},
#   'DAPO-D': {'last_checked_date': '2025,12,12,09:31',
#    'cutoff_date': '2025,03,25'},
#   'DAKIRO-D': {'last_checked_date': '2025,12,24,18:22',
#    'cutoff_date': '2022,04,12'},
#   'DACHVO-D': {'last_checked_date': '2025,12,21,09:19',
#    'cutoff_date': '2024,08,23'},
#   'OMELNIK-_': {'last_checked_date': '2025,12,26,08:26',
#    'cutoff_date': '2024,07,30'},
#   'IMFE-_': {'last_checked_date': '2025,12,27,08:37',
#    'cutoff_date': '2018,07,31'},
#   'GDA-SZRU': {'last_checked_date': '2025,12,26,09:56',
#    'cutoff_date': '2021,02,13'},
#   'CDIAK-_': {'last_checked_date': '2025,12,24,18:39',
#    'cutoff_date': '2025,04,10'},
# ...

# %%
user.keys()
# Out:
# dict_keys(['name', 'password', 'watchlist', 'preferences'])

# %%
user["watchlist"]
# Out:
# {'DAHMO-K': {'last_checked_date': '2025,12,02,11:51',
#   'cutoff_date': '2019,01,01'},
#  'DAPO-D': {'last_checked_date': '2025,12,12,09:31',
#   'cutoff_date': '2025,03,25'},
#  'DAKIRO-D': {'last_checked_date': '2025,12,24,18:22',
#   'cutoff_date': '2022,04,12'},
#  'DACHVO-D': {'last_checked_date': '2025,12,21,09:19',
#   'cutoff_date': '2024,08,23'},
#  'OMELNIK-_': {'last_checked_date': '2025,12,26,08:26',
#   'cutoff_date': '2024,07,30'},
#  'IMFE-_': {'last_checked_date': '2025,12,27,08:37',
#   'cutoff_date': '2018,07,31'},
#  'GDA-SZRU': {'last_checked_date': '2025,12,26,09:56',
#   'cutoff_date': '2021,02,13'},
#  'CDIAK-_': {'last_checked_date': '2025,12,24,18:39',
#   'cutoff_date': '2025,04,10'},
#  'DAIFO-D': {'last_checked_date': '2025,12,26,13:56',
#   'cutoff_date': '2024,10,08'},
#  'DISZMO-Digital collections': {'last_checked_date': '2025,12,26,13:56',
#   'cutoff_date': '2024,08,04'},
#  'DAZPO-R': {'last_checked_date': '2025,12,17,08:29',
# ...
