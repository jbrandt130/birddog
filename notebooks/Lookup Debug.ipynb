# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
# uncomment to use hosted db
del os.environ["BIRDDOG_USE_LOCAL_NOCODB"]
if os.environ.get("BIRDDOG_USE_LOCAL_NOCODB"):
    print("using local nocodb")
else:
    print("using aws nocodb")
# Out:
# using aws nocodb

# %%
from birddog.database import Database
# Out:
# 2026-07-20 08:00:23,178 [INFO] Using aws nocodb api: http://nocodb-env.eba-xhmfyydr.us-east-2.elasticbeanstalk.com

# %%
db = Database()
# Out:
# 2026-07-20 08:00:24,491 [INFO] creating NocoDBDatabase(host=http://nocodb-env.eba-xhmfyydr.us-east-2.elasticbeanstalk.com, base_id=prsjtz30iuhk88f) instance
# 2026-07-20 08:00:24,712 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   nocodb.internal:api                   20.00     4.57    39.00       0.00           24

# %%
records, _ = db.scan("Documents", view_name="BD:Missing Metadata", limit=200)

# %%
len(records)
# Out:
# 35

# %%
records[0]
# Out:
# {'Id': 400438,
#  'title': 'File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf',
#  'url': 'https://uk.wikisource.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf',
#  'sha1_hash': None,
#  'availability': None,
#  'wiki': True,
#  'years': None,
#  'reference_date': None}

# %%
recs, _ = db.scan(
    "Documents", 
    where=(
        "url",
        "eq",
        "https://uk.wikisource.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf"
    )
)
# Out:
# 2026-07-20 08:07:41,300 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   nocodb.internal:api                   24.00     0.01    39.00       0.00           24

# %%
urls = [r["url"] for r in records]

# %%
db.lookup("Documents", urls[0])
# Out:
# 400478

# %%
for u in urls:
    print(u, db.lookup("Documents", u))
# Out:
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf 400478
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-984_План_частини_найдавнішої_фортеці_поблизу_м._Махнівка_Махнівського_повіту_на_лівому..._(1844).pdf 400479
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-976_Плани_церковних_земельних_ділянок_м-ка_Вахнівка_Махнівського_повіту,_відмежованих_від..._(1816-1819).pdf 400480
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-980_План_земельних_ділянок_м-ка_Козятин_Бердичівського_повіту,_що_належать_поміщику..._(1903).pdf 400481
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-980_План_земельних_ділянок_м-ка_Козятин_Бердичівського_повіту,_що_належать_поміщику..._(1903).pdf 400482
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-981_План_м-ка_Махнівка_Махнівського_(з_1846_р._-_Бердичівського)_повіту_(1782-1919).pdf 400483
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-976_Плани_церковних_земельних_ділянок_м-ка_Вахнівка_Махнівського_повіту,_відмежованих_від..._(1816-1819).pdf 400484
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-973_План_земельних_ділянок_казенних_селян_м-ка_Білилівка_Бердичівського_повіту_(1872).pdf 400485
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-99_Плани_садибних_ділянок_на_Лютеранській_вулиці,_відведених_у_кварталі,_призначеному_для..._(1852-1854).pdf 400486
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-974_План_церковних_земельних_ділянок_м-ка_Білилівка_Махнівського_повіту,_відмежованих_від..._(1819).pdf 400487
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-975_План_земельних_ділянок_м-ка_Вахнівка_Бердичівського_повіту,_що_належать_Гропімківському_(1863).pdf 400488
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-972_План_церковних_земельних_ділянок_біля_м-ка_Білилівка_Махнівського_повіту_(1806).pdf 400489
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-982_План_розверстання_земель_Струкова-Левандовського_на_відрубні_ділянки_в_м-ку_Махнівка..._(1914).pdf 400490
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-983_План_церковних_земельних_ділянок_м-ка_Махнівка_Махнівського_повіту,_відмежованих_від..._(1812).pdf 400491
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-99_Плани_садибних_ділянок_на_Лютеранській_вулиці,_відведених_у_кварталі,_призначеному_для..._(1852-1854).pdf 400492
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-986_План_садибної_ділянки_Горденіних_у_м-ку_Нова_Прилука_Бердичівського_повіту_(1906).pdf 400493
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-975_План_земельних_ділянок_м-ка_Вахнівка_Бердичівського_повіту,_що_належать_Гропімківському_(1863).pdf 400494
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-986_План_садибної_ділянки_Горденіних_у_м-ку_Нова_Прилука_Бердичівського_повіту_(1906).pdf 400495
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-985_План_церковних_земельних_ділянок_м-ка_Прилука_Махнівського_повіту,_відмежованих_від..._(1817).pdf 400496
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-978_Плани_земельних_ділянок_м-ка_Вахнівка_Бердичівського_повіту,_що_належать_до_Селянського..._(1912).pdf 400497
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-981_План_м-ка_Махнівка_Махнівського_(з_1846_р._-_Бердичівського)_повіту_(1782-1919).pdf 400498
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-988_План_церковних_земельних_ділянок_с._Бродецьке_Махнівського_повіту_(1807).pdf 400499
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf 400500
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-978_Плани_земельних_ділянок_м-ка_Вахнівка_Бердичівського_повіту,_що_належать_до_Селянського..._(1912).pdf 400501
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-987_Плани_церковних_земельних_ділянок_м-ка_Погребище_Махнівського_повіту,_відмежованих_від..._(1833).pdf 400502
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-979_Плани_церковних_земельних_ділянок_м-ка_Дзюньків_Махнівського_повіту,_відмежованих_від..._(1816-1819).pdf 400503
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-987_Плани_церковних_земельних_ділянок_м-ка_Погребище_Махнівського_повіту,_відмежованих_від..._(1833).pdf 400504
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-985_План_церковних_земельних_ділянок_м-ка_Прилука_Махнівського_повіту,_відмежованих_від..._(1817).pdf 400505
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-984_План_частини_найдавнішої_фортеці_поблизу_м._Махнівка_Махнівського_повіту_на_лівому..._(1844).pdf 400506
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-988_План_церковних_земельних_ділянок_с._Бродецьке_Махнівського_повіту_(1807).pdf 400507
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-977_Плани_викупних_селянських_земельних_ділянок_м-ка_Вахнівка_Бердичівського_повіту,..._(1907).pdf 400508
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-98_План_садибної_ділянки_на_Левашівській_вулиці,_відведеної_під_будівництво_житлового..._(1782-1919).pdf 400509
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-972_План_церковних_земельних_ділянок_біля_м-ка_Білилівка_Махнівського_повіту_(1806).pdf 400510
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-979_Плани_церковних_земельних_ділянок_м-ка_Дзюньків_Махнівського_повіту,_відмежованих_від..._(1816-1819).pdf 400511
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-974_План_церковних_земельних_ділянок_м-ка_Білилівка_Махнівського_повіту,_відмежованих_від..._(1819).pdf 400512

# %%
for u in urls:
    if "," not in u:
        print(u)
# Out:
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-984_План_частини_найдавнішої_фортеці_поблизу_м._Махнівка_Махнівського_повіту_на_лівому..._(1844).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-981_План_м-ка_Махнівка_Махнівського_(з_1846_р._-_Бердичівського)_повіту_(1782-1919).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-973_План_земельних_ділянок_казенних_селян_м-ка_Білилівка_Бердичівського_повіту_(1872).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-972_План_церковних_земельних_ділянок_біля_м-ка_Білилівка_Махнівського_повіту_(1806).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-982_План_розверстання_земель_Струкова-Левандовського_на_відрубні_ділянки_в_м-ку_Махнівка..._(1914).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-986_План_садибної_ділянки_Горденіних_у_м-ку_Нова_Прилука_Бердичівського_повіту_(1906).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-986_План_садибної_ділянки_Горденіних_у_м-ку_Нова_Прилука_Бердичівського_повіту_(1906).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-981_План_м-ка_Махнівка_Махнівського_(з_1846_р._-_Бердичівського)_повіту_(1782-1919).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-988_План_церковних_земельних_ділянок_с._Бродецьке_Махнівського_повіту_(1807).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-989_План_земельної_ділянки_Підгірського_у_с._Бродецьке_Бердичівського_повіту_(1909).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-984_План_частини_найдавнішої_фортеці_поблизу_м._Махнівка_Махнівського_повіту_на_лівому..._(1844).pdf
# https://uk.wikisource.org/wiki/File:ДАКО_1542-1-988_План_церковних_земельних_ділянок_с._Бродецьке_Махнівського_повіту_(1807).pdf
# https://commons.wikimedia.org/wiki/File:ДАКО_1542-1-972_План_церковних_земельних_ділянок_біля_м-ка_Білилівка_Махнівського_повіту_(1806).pdf

# %%
for u in urls:
    r, _ = db.scan("Documents", where=("url","eq",u))
    if len(r) != 2:
        print(f"{u} --> {len(r)}")

# %%
docs = db.get_all_ids("Documents")

# %%
(len(pages), len(docs))

# %%
db.delete("Documents", docs)

# %%
db.delete("Pages", pages)

# %%
r,_ = db.scan("Documents", view_name="BD:WDT:commons.wikimedia.org")

# %%
db._field_id("Documents", "owning_pages")

# %%
db._field_id("Pages", "parent")

# %%
rename_field(db, db._field_id("Pages", "Pages"), "parent")

# %%
len(pages)

# %%
db.delete("Pages", pages)

# %%
docs = db.get_all_ids("Documents")

# %%
len(docs)

# %%
db.delete("Documents", docs)

# %%
pages = []
cursor = None
while True:
    if cursor and (int(cursor) % 10000) == 0:
        print(f"cursor={cursor}")
    batch, cursor = db.scan(
        "Pages", 
        cursor=cursor, 
        limit=1000,
        where=("seq_label", "is", None),
        fields=("Id","title","label","seq_label"),
    )
    if batch:
        pages.extend(batch)
    if not cursor:
        break

# %%
len(pages)

# %%
pages[1000]

# %%
def normalize_labels(page):
    result = page.copy()
    title = page.get("title")
    if title:
        proper_label = page_label(title)
        result["label"] = proper_label
        proper_seq_label = sequential_page_label(proper_label)
        result["seq_label"] = proper_seq_label
    return result

# %%
normalize_labels(pages[2000])

# %%
pages[2000]

# %%
pages[2000] == normalize_labels(pages[2000])

# %%
pages[2000] == pages[2000].copy()

# %%
norm_pages = [normalize_labels(p) for p in pages]

# %%
norm_pages[:10]

# %%
changed_pages = [n for n,p in zip(norm_pages, pages) if n != p]

# %%
len(changed_pages)

# %%
len(pages)

# %%
len(norm_pages)

# %%
rec_ids = db.write("Pages", norm_pages[1000:2000])

# %%
chunk = 1000
for i in range(0, len(norm_pages), chunk):
    print(i)
    rec_ids = db.write("Pages", norm_pages[i:(i+chunk)])
