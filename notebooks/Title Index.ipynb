# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import ARCHIVES, WIKI_NAMESPACE
from birddog.core import PageLRU, TitleIndex
# Out:
# 2025-07-01 19:52:32,035 [INFO] Using Google Cloud translation API (credentials file:/Users/jbrandt/code/birddog/google-cloud-translate-key.json)
# 2025-07-01 19:52:32,045 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.

# %%
page_lru = PageLRU()

# %%
title_index = TitleIndex(page_lru=page_lru)

# %%
for root, addresses in title_index._archives.items():
    for address in addresses:
        page = page_lru.lookup(*address)
        print(root, page.title)

# %%
for title, address in title_index._index.items():
    page = page_lru.lookup(*address)
    print(title, page.title)
    if not title == f"{WIKI_NAMESPACE}:{page.title}":
        print("MISMATCH")

# %%
for title in title_index._index.keys():
    print(title, title_index.lookup(title))

# %%
titles = [ 
    "Архів:ДАЖО/1/1",
    "Архів:ДАК/312/1",
    "Архів:ДАЖО/1/74",
    "Архів:Лука_Мала",
    "Архів:ЦДІАК/1/1",
    "Архів:ДАХО/Д",
    "Архів:ДАПО/Р/1–1000",
    "Архів:ЦДІАК/28",
    "Архів:ЦДІАК/28/1",
    "Архів:ДАЖО/1",
    "Архів:ДАК/Р-352",
    "Архів:Архівний відділ виконавчого комітету Кременчуцької міської ради/Р",
    "Архів:ДАЖО/Д",
    "Архів:ДАДнО/Р-6478/2", 
    "Архів:ДАЖО/752", 
    "Архів:ДАКрО/225/1/25", 
    "Архів:ДАКрО/225", 
    "Архів:ДАСО/Р", 
    "Архів:ДАХмО/К", 
    "Архів:ДАКрО/225/1/144а", 
    "Архів:ДАПО/978/1",
    "Архів:ДАПО/Р",
    "Архів:ДАХмО/Р-6193",
    "Архів:ДАКрО/П-5907/2Р",
    "Архів:ДАОО/Р-8085/1",
    "Архів:ДАКрО/225/1",
    "Архів:ДАПО/1072/1/1",
    "Архів:ДАПО/978/1/135",
    "Архів:ДАПО/978",
    ]

# %%
for title in titles:
    address = title_index.lookup(title)
    #print(title, address)
    page = page_lru.lookup(*address)
    print(title, address, page.title)
    if not title == f"{WIKI_NAMESPACE}:{page.title}":
        print("====> MISMATCH:", page.url)

# %%
title_index.to_dict()

# %%
title_index.lookup_archive_root("DAZHO", "P")

# %%
title_index.lookup_archive_root("AVPRI", "_")
# Out:
# 'Архів:АВПРИ'

# %%
from birddog.wiki import get_all_pages

# %%
get_all_pages(prefix=title_index.lookup_archive_root("AVPRI", "_"))
# Out:
# 2025-07-01 19:55:41,878 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# ['Архів:АВПРИ', 'Архів:АВПРИ/124', 'Архів:АВПРИ/124/1', 'Архів:АВПРИ/124/1/62']
