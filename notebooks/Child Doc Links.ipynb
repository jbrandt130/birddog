# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import (
    batch_fetch_document_links,
    _read_wiki_text,
    mw_read_page,
)

# %%
titles = [
    "Архів:ДАВіО/635/1/11",
    "Архів:ДАКО/280/2/1475",
]

# %%
result = batch_fetch_document_links(titles)
# Out:
# 2025-11-12 21:22:54,551 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s

# %%
result
# Out:
# {'Архів:ДАВіО/635/1/11': ['/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_1.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_2.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_3.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_4.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_5.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_6.pdf',
#   '/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_7.pdf',
#   "/wiki/File:ДАВіО_635-1-11_Список_євреїв_містечка_М'ястківка_(ревізька_казка,_лл.541-581)_(1795).pdf"],
#  'Архів:ДАКО/280/2/1475': ['/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._(1858).pdf',
#   '/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._т.2_(1858).pdf',
#   '/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._(1858).pdf]]',
#   '/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._т.2_(1858).pdf]]']}

# %%
mw_read_page(titles[1])
# Out:
# 2025-11-12 21:27:30,397 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# {'title': {'uk': 'ДАКО/280/2/1475'},
#  'template': {'uk': 'Архіви/справа'},
#  'revid': 963836,
#  'description': {'uk': 'Ревізькі казки громадян, однодворців, вільних людей і дворових, євреїв-хліборобів Радомисльського повіту, том 1.\nРевізькі казки громадян, однодворців, вільних людей і дворових, євреїв-хліборобів Радомисльського повіту, том 2'},
#  'dates': {'uk': '1858', 'en': '1858'},
#  'notes': {'commons_links': ['https://commons.wikimedia.org/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._(1858).pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._т.2_(1858).pdf'],
#   'category_links': [],
#   'internal_links': [],
#   'external_links': []},
#  'other_links': {'commons_links': [],
#   'category_links': ['Категорія:Радомисльський повіт',
#    'Категорія:ДАКО фонд 280 опис 2'],
#   'internal_links': ['File:ДАКО 280-2-1475 Ревізькі казки громадян, однодворців, вільних людей і дворових, євреїв-хліборобів... (1858).pdf',
#    'File:ДАКО 280-2-1475 Ревізькі казки громадян, однодворців, вільних людей і дворових, євреїв-хліборобів... т.2 (1858).pdf'],
#   'external_links': []},
#  'tables': [],
#  'lastmod': '2025,08,09,16:23',
#  'link': 'https://uk.wikisource.org/wiki/Архів:ДАКО/280/2/1475',
#  'doc_link': 'https://uk.wikisource.org/wiki/File:ДАКО_280-2-1475_Ревізькі_казки_громадян,_однодворців,_вільних_людей_і_дворових,_євреїв-хліборобів..._(1858).pdf'}

# %%
mw_read_page(titles[0])
# Out:
# 2025-11-12 21:28:42,655 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# {'title': {'uk': 'ДАВіО/635/1/11'},
#  'template': {'uk': 'Архіви/справа'},
#  'revid': 943379,
#  'description': {'uk': 'Ревізькі казки Ольгопільського та Бершадського повітів'},
#  'dates': {'uk': '1795', 'en': '1795'},
#  'notes': {'commons_links': ['https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_1.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_2.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_3.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_4.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_5.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_6.pdf',
#    'https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_7.pdf',
#    "https://commons.wikimedia.org/wiki/File:ДАВіО_635-1-11_Список_євреїв_містечка_М'ястківка_(ревізька_казка,_лл.541-581)_(1795).pdf"],
#   'category_links': [],
#   'internal_links': [],
#   'external_links': []},
#  'other_links': {'commons_links': [],
#   'category_links': ['Категорія:Ольгопільський повіт',
#    'Категорія:Бершадський повіт',
#    'Категорія:Ревізькі казки Подільської губернії 1795 року'],
#   'internal_links': ['File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 1.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 2.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 3.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 4.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 5.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 6.pdf',
#    'File:ДАВіО 635-1-11 1795 Ревізькі казки Ольгопільського та Бершадського повітів - 7.pdf',
#    "File:ДАВіО 635-1-11 Список євреїв містечка М'ястківка (ревізька казка, лл.541-581) (1795).pdf",
#    'Городківка (Тульчинський район)'],
#   'external_links': []},
#  'tables': [],
#  'lastmod': '2025,07,02,08:00',
#  'link': 'https://uk.wikisource.org/wiki/Архів:ДАВіО/635/1/11',
#  'doc_link': 'https://uk.wikisource.org/wiki/File:ДАВіО_635-1-11_1795_Ревізькі_казки_Ольгопільського_та_Бершадського_повітів_-_1.pdf'}
