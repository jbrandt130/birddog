# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import (
    batch_fetch_document_links,
    _read_wiki_text,
    mw_read_page,
)
# Out:
# 2026-05-27 10:47:51,904 [INFO] Translation is enabled. Using GCP translator
# 2026-05-27 10:47:51,905 [INFO] Using Google Cloud translation API
# 2026-05-27 10:47:51,905 [INFO] GoogleCloudTranslator using REST API

# %%
titles = [
#    "Архів:ДАДнО/К/Ф",
#    "Архів:ДАКрО/Р-293/1",
#    "Архів:ДАВіО/635/1/11",
#    "Архів:ДАКО/280/2/1475",
    "Архів:ДАСО/993/1/15",
]

# %%
result = batch_fetch_document_links(titles)
# Out:
# 2026-05-27 10:47:52,905 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   uk.wikisource.org:api                  4.00     5.11     4.00       0.00            4

# %%
result
# Out:
# {'Архів:ДАСО/993/1/15': [{'link': 'https://commons.wikimedia.org/wiki/File:ДАСО_993-1-15_Ревизские_сказки_о_купцах_и_мещанах_гор._Ромен_и_гор._Глинска;_о_казенных_крестьянах..._(1811-1833).pdf',
#    'exists': True}]}

# %%
mw_read_page(titles[1])

# %%
mw_read_page(titles[0])
