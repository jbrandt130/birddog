# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.core import (
    Archive,
)
from birddog.wiki import (
    get_recent_changes,
    lookup_namespace_id,
    get_all_pages,
    get_last_mod,
    get_page_history,
    PageTracker,
    batch_page_exists,
    page_exists,
    ARCHIVES_BY_ROOT, 
    ARCHIVE_BY_TITLE, 
    ARCHIVE_BY_ADDRESS
    )
# Out:
# 2025-08-16 10:52:24,367 [INFO] Using Google Cloud translation API (credentials file:/Users/jbrandt/code/birddog/google-cloud-translate-key.json)
# 2025-08-16 10:52:24,372 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.

# %%
tracker = PageTracker()

# %%
#tracker.update()

# %%
u=tracker.get_updates("Архів:ДАДнО")

# %%
len(list(u.keys()))
# Out:
# 831

# %%
for k in u.keys():
    if "Р-6508/14" in k:
        print(k, u[k])
# Out:
# Архів:ДАДнО/Р-6508/14д 2025,07,29,10:23
# Архів:ДАДнО/Р-6508/14д/6 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/4 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/3 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/28 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/25 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/19 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/12 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14д/1 2025,07,29,10:22
# Архів:ДАДнО/Р-6508/14 2025,07,29,10:19
# Архів:ДАДнО/Р-6508/14/36 2025,07,29,10:17
# Архів:ДАДнО/Р-6508/14/26 2025,07,29,10:17
# Архів:ДАДнО/Р-6508/14/176 2025,07,29,10:17
# Архів:ДАДнО/Р-6508/14/145 2025,07,29,10:17
# Архів:ДАДнО/Р-6508/14/136 2025,07,29,10:17
# Архів:ДАДнО/Р-6508/14/13 2025,07,29,10:17

# %%
import json

# %%
with open(".cache/watchers/jon4@test.com/DAVIO-D.json") as file:
    w_data = json.loads(file.read())

# %%
w = ArchiveWatcher.load(w_data, runtime=runtime)
