# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.core import (
    Archive,
)
from birddog.wiki import (
    get_recent_changes,
    lookup_namespace_id,
    get_all_pages,
    get_last_mod,
    get_page_history,
    PageTracker,
    batch_page_exists,
    page_exists,
    ARCHIVES_BY_ROOT, 
    ARCHIVE_BY_TITLE, 
    ARCHIVE_BY_ADDRESS
    )
# Out:
# 2025-08-16 13:13:41,053 [INFO] Using Google Cloud translation API (credentials file:/Users/jbrandt/code/birddog/google-cloud-translate-key.json)
# 2025-08-16 13:13:41,057 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.

# %%
tracker = PageTracker()

# %%
#tracker.update()

# %%
u=tracker.get_updates("Архів:ДАХмО")

# %%
len(list(u.keys()))

# %%
for k in list(u.keys())[:10]:
    print(k, u[k])

# %%
min(u.values())

# %%
pgs = get_all_pages(prefix="Архів:ДАХмО")
# Out:
# 2025-08-16 13:16:49,433 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s

# %%
len(pgs)
# Out:
# 16988

# %%
import json

# %%
#with open(".cache/watchers/jon4@test.com/DAVIO-D.json") as file:
#    w_data = json.loads(file.read())

# %%
#w = ArchiveWatcher.load(w_data, runtime=runtime)

# %%
with open(".cache/page_update_manager.json") as file:
    pum_data = json.loads(file.read())

# %%
pending = pum_data["pending_titles"]

# %%
len(pending)
# Out:
# 72186

# %%
pum_data["registered_archives"]
# Out:
# ['GDA-MO',
#  'TSDIAL-_',
#  'DAPO-D',
#  'DAVIO-D',
#  'DADNO-R',
#  'DAPO-R',
#  'DAHMO-D',
#  'DASO-D',
#  'DASO-R',
#  'DAHO-D',
#  'DAVIO-R']

# %%
import time

# %%
time.sleep(1)
