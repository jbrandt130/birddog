# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.logging import (
    ServiceLogger,
    SQLLiteEventLogger,
    DynamoDBEventLogger,
    SQLLiteServiceLogger,
    DynamoDBServiceLogger,
    _to_iso_utc_str,
    )
from datetime import datetime, timedelta, UTC
import pandas as pd

# %%
logger = SQLLiteEventLogger()

# %%
logger.load_logs('2025,11,01', '2025,11,15')

# %%
_to_iso_utc_str('2025,11,01')

# %%
now = datetime.now()

# %%
now

# %%
_to_iso_utc_str(datetime(2025,11,1))

# %%
logger.load_logs(datetime(2025,11,1),datetime(2025,11,15))

# %%
logger.truncate(datetime(2025,9,30))

# %%
logger = SQLLiteServiceLogger()

# %%
logger.load_logs(datetime(2025,9,1),datetime(2025,12,1))

# %%
logger.truncate(datetime(2025,9,30))

# %%
logger.load_logs(datetime(2025,9,1),datetime(2025,12,1))

# %%
logger = DynamoDBEventLogger()

# %%
logger.truncate(datetime(2025,9,1))
# Out:
# 0

# %%
logger = DynamoDBServiceLogger()

# %%
logger.truncate(datetime(2025,9,1))
# Out:
# 0
