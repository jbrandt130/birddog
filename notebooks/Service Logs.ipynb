# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.logging import ServiceLogger
from datetime import datetime, timedelta, UTC
import pandas as pd

# %%
logger = ServiceLogger.get_logger()

# %%
now = datetime.now(UTC)
delta = timedelta(days=1)
df = logger.load_logs(now - delta, now)

# %%
df
# Out:
#         id                  timestamp     resource   method  \
# 0        1 2025-09-07 22:17:00.250527     local_fs     load
# 1        2 2025-09-07 22:17:00.252186      KVStore  get_all
# 2        3 2025-09-07 22:17:00.253148  StringQueue     peek
# 3        4 2025-09-07 22:17:00.917646     local_fs     load
# 4        5 2025-09-07 22:17:00.920219      KVStore  get_all
# ...    ...                        ...          ...      ...
# 9326  9327 2025-09-08 17:01:00.276164  StringQueue     peek
# 9327  9328 2025-09-08 17:01:05.284086      KVStore  get_all
# 9328  9329 2025-09-08 17:01:05.287944  StringQueue     peek
# 9329  9330 2025-09-08 17:01:10.294605      KVStore  get_all
# 9330  9331 2025-09-08 17:01:10.303849  StringQueue     peek
#
#                                path  size  duration
# 0          page_update_manager.json   244         0
# 1     TranslationManager:in_process     2         0
# 2        TranslationManager:pending     2         0
# 3          page_update_manager.json   244         0
# 4     TranslationManager:in_process     2         1
# ...                             ...   ...       ...
# 9326     TranslationManager:pending     2         3
# 9327  TranslationManager:in_process     2         1
# 9328     TranslationManager:pending     2         0
# 9329  TranslationManager:in_process     2         1
# 9330     TranslationManager:pending     2         2
#
# [9331 rows x 7 columns]

# %%
ServiceLogger.summarize_service_usage(df, sample_interval_minutes=24*60)
# Out:
#            resource               method  count  cumulative_size  \
# 0   DummyTranslator            translate    105           105483
# 1           KVStore                count    236                0
# 2           KVStore                  get    231            41419
# 3           KVStore              get_all   3314           442955
# 4           KVStore               insert    697          1056309
# 5           KVStore               remove    235             6777
# 6           KVStore           remove_all      4                0
# 7      ModDateStore  batch_store_updates      8             2015
# 8      ModDateStore    get_newer_updates     66         34834769
# 9      ModDateStore      query_by_prefix     72         12255570
# 10      StringQueue               append      4           739882
# 11      StringQueue                 peek   3756            22183
# 12      StringQueue                  pop    240           741748
# 13         local_fs                 load    179         33679412
# 14         local_fs                 save    184         27971869
#
#     cumulative_duration  count_per_minute  size_per_minute
# 0                     0          0.072917        73.252083
# 1                     0          0.163889         0.000000
# 2                    21          0.160417        28.763194
# 3                  3217          2.301389       307.607639
# 4                   278          0.484028       733.547917
# 5                   176          0.163194         4.706250
# 6                     3          0.002778         0.000000
# 7                    24          0.005556         1.399306
# 8                  2143          0.045833     24190.811806
# 9                   377          0.050000      8510.812500
# 10                    6          0.002778       513.806944
# 11                 1236          2.608333        15.404861
# 12                   95          0.166667       515.102778
# 13                  140          0.124306     23388.480556
# 14                   24          0.127778     19424.909028

# %%
s=summarize_service_log(df, by="resource")

# %%
val = s.loc[s["resource"].eq("StringQueue"), "cumulative_size"]
cumulative = int(val.iloc[0]) if not val.empty else 0
cumulative

# %%
v = cumulative_size

# %%
td=timedelta(**v)

# %%
s

# %%
td.min

# %%
td

# %%
td.total_seconds()

# %%
delta.total_seconds()

# %%
summarize_service_log(df)

# %%
    grouped = (
        tmp.groupby(["resource", "method"], dropna=False, observed=True)
           .agg(
               count=("resource", "size"),                 # number of rows in group
               cumulative_size=("size", "sum"),            # bytes
               cumulative_duration=("duration", "sum"),    # seconds
           )
           .reset_index()
    )
