# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.logging import ServiceLogger
from datetime import datetime, timedelta, UTC
import pandas as pd

# %%
logger = ServiceLogger.get_logger()

# %%
now = datetime.now(UTC)
delta = timedelta(days=1)
df = logger.load_logs(now - delta, now)

# %%
df

# %%
ServiceLogger.summarize_service_usage(df, sample_interval_minutes=24*60)

# %%
s=summarize_service_log(df, by="resource")

# %%
val = s.loc[s["resource"].eq("StringQueue"), "cumulative_size"]
cumulative = int(val.iloc[0]) if not val.empty else 0
cumulative

# %%
v = cumulative_size

# %%
td=timedelta(**v)

# %%
s

# %%
td.min

# %%
td

# %%
td.total_seconds()

# %%
delta.total_seconds()

# %%
from birddog.logging import DynamoDBServiceLogger

# %%
logger = DynamoDBServiceLogger()

# %%
now = datetime.now(UTC)
delta = timedelta(minutes=5)
df = logger.load_logs(now - delta, now)

# %%
df.empty
# Out:
# True

# %%
s = ServiceLogger.summarize_service_usage(df, by="resource", sample_interval_minutes=delta.total_seconds() / 60.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s = ServiceLogger.summarize_service_usage(df, by="resource", sample_interval_minutes=delta.total_seconds() / 60.)
#
# File ~/code/birddog/birddog/logging.py:313, in ServiceLogger.summarize_service_usage(df, by, sample_interval_minutes)
#     311 missing = needed - set(df.columns)
#     312 if missing:
# --> 313     raise ValueError(f"Missing required columns: {', '.join(sorted(missing))}")
#     315 # Coerce types
#     316 size = pd.to_numeric(df["size"], errors="coerce").fillna(0)
#
# ValueError: Missing required columns: duration, resource, size

# %%
df

# %%
s

# %%
len(df)

# %%
if not df:
    print("empty")

# %%
df.empty

# %%
if df:
    print("ok")

# %%
summarize_service_log(df)

# %%
    grouped = (
        tmp.groupby(["resource", "method"], dropna=False, observed=True)
           .agg(
               count=("resource", "size"),                 # number of rows in group
               cumulative_size=("size", "sum"),            # bytes
               cumulative_duration=("duration", "sum"),    # seconds
           )
           .reset_index()
    )
