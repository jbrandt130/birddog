# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.tracker import (
    #migrate_page_tracker_to_kv,
    #migrate_page_change_log_to_kv,
    PageChangeLog,
    PageTracker,
    )
from birddog.wiki import (
    get_recent_changes,
)
# Out:
# 2026-04-25 10:11:14,669 [INFO] Translation is enabled. Using GCP translator
# 2026-04-25 10:11:14,670 [INFO] Using Google Cloud translation API
# 2026-04-25 10:11:14,670 [INFO] GoogleCloudTranslator using REST API

# %%
#migrate_page_tracker_to_kv(force_ddb=True)

# %%
#migrate_page_change_log_to_kv(force_ddb=True)

# %%
log = PageChangeLog()

# %%
log.refresh()
# Out:
# 2026-04-25 10:11:20,817 [INFO]
# service throttle report:
#   host_key                            cfg_rps  act_rps   tokens  blocked_s max_in_flight
#   ----------------------------------------------------------------------------------------
#   uk.wikisource.org:api                  4.00     2.80     4.00       0.00            4
# 2026-04-25 10:11:20,820 [INFO] PageChangeLog: recording 7 new page changes

# %%
changes = log.get()

# %%
len(changes)
# Out:
# 30938

# %%
list(changes.keys())[:10]
# Out:
# ['Архів:LMAVB',
#  'Архів:LMAVB/16',
#  'Архів:LMAVB/16/1867',
#  'Архів:OMR',
#  'Архів:Єврейське_містечко',
#  'Архів:Єврейське_містечко/Волинська_губернія',
#  'Архів:Єврейське_містечко/Герцогство_Буковина',
#  'Архів:Єврейське_містечко/Катеринославська_губернія',
#  'Архів:Єврейське_містечко/Київська_губернія',
#  'Архів:Єврейське_містечко/Подільська_губернія']

# %%
changes["Архів:ЦДІАЛ/146"]
# Out:
# {'timestamp': '2026,04,17,19:02', 'user': '~2026-23669-94'}

# %%
changes["Архів:ЦДІАЛ/146/17"]
# Out:
# {'timestamp': '2026,04,17,20:55', 'user': 'Madvin'}

# %%
c = get_recent_changes()

# %%
len(c)
# Out:
# 8239

# %%
c["Архів:ЦДІАЛ/146/17"]
# Out:
# {'timestamp': '2026-04-17T20:55:29Z', 'user': 'Madvin', 'action': 'delete'}
