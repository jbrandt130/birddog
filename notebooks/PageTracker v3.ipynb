# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.excel import (
    export_page,
    )
# Out:
# 2026-04-27 08:57:30,377 [INFO] Translation is enabled. Using GCP translator
# 2026-04-27 08:57:30,378 [INFO] Using Google Cloud translation API
# 2026-04-27 08:57:30,378 [INFO] GoogleCloudTranslator using REST API
# 2026-04-27 08:57:30,694 [INFO] Using local folder /Users/jbrandt/code/birddog/.cache for storage.

# %%
title =
