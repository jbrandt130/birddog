# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.tracker import (
    migrate_page_tracker_to_kv,
    migrate_page_change_log_to_kv,
    )
# Out:
# 2026-02-20 14:06:00,109 [INFO] Translation is enabled. Using GCP translator
# 2026-02-20 14:06:00,110 [INFO] Using Google Cloud translation API
# 2026-02-20 14:06:00,110 [INFO] GoogleCloudTranslator using REST API

# %%
migrate_page_tracker_to_kv(force_ddb=True)
# Out:
# 2026-02-20 14:06:19,990 [INFO] Found credentials in environment variables.
# 2026-02-20 14:06:48,167 [INFO] migrate_page_tracker_to_kv: 177771 rows
# 2026-02-20 17:07:11,334 [INFO] migrate_page_tracker_to_kv: done

# %%
migrate_page_change_log_to_kv(force_ddb=True)
# Out:
# 2026-02-20 17:11:04,886 [INFO] migrate_page_change_log_to_kv: 21721 entries (from 71535 rows)
# 2026-02-20 17:31:02,092 [INFO] migrate_page_change_log_to_kv: done
