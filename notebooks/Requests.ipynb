# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import (
    API_URL
)
from birddog.fetch import (
    fetch_url,
)

# %%
fetch_url(
    API_URL, 
    params = {
        "action": "query",
        "format": "json",
        "meta": "siteinfo",
        "siprop": "namespaces|namespacealiases"
    },        
    return_json=True)
# Out:
# {'batchcomplete': '',
#  'query': {'namespaces': {'-2': {'id': -2,
#     'case': 'first-letter',
#     'canonical': 'Media',
#     '*': 'Медіа'},
#    '-1': {'id': -1,
#     'case': 'first-letter',
#     'canonical': 'Special',
#     '*': 'Спеціальна'},
#    '0': {'id': 0,
#     'case': 'first-letter',
#     'subpages': '',
#     'content': '',
#     '*': ''},
#    '1': {'id': 1,
#     'case': 'first-letter',
#     'subpages': '',
#     'canonical': 'Talk',
#     '*': 'Обговорення'},
#    '2': {'id': 2,
#     'case': 'first-letter',
#     'subpages': '',
#     'canonical': 'User',
#     '*': 'Користувач'},
#    '3': {'id': 3,
#     'case': 'first-letter',
#     'subpages': '',
#     'canonical': 'User talk',
#     '*': 'Обговорення користувача'},
#    '4': {'id': 4,
#     'case': 'first-letter',
#     'subpages': '',
#     'canonical': 'Project',
#     '*': 'Вікіджерела'},
#    '5': {'id': 5,
#     'case': 'first-letter',
#     'subpages': '',
#     'canonical': 'Project talk',
# ...
