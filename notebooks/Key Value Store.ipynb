# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.store import get_key_value_store, DynamoDBKeyValueStore

# %%
store = DynamoDBKeyValueStore()
# Out:
# 2025-09-18 08:35:50,263 [INFO] Found credentials in environment variables.

# %%
store.insert("test", "a", "5")

# %%
kv = get_key_value_store()

# %%
kv.count("foo")
# Out:
# 0

# %%
ns = "test_namespace"

# %%
kv.insert(ns, "a", "x")

# %%
kv.get(ns, "a")
# Out:
# 'x'

# %%
kv.count(ns)
# Out:
# 1

# %%
kv.insert(ns, "b", "y")

# %%
kv.remove(ns, "c")

# %%
try:
    kv.get(ns, "c")
except KeyError:
    pass

# %%
kv.get_all(ns)
# Out:
# [('a', 'x'), ('b', 'y')]

# %%
kv.insert(ns, "c", "z")

# %%
kv.get_all(ns)
# Out:
# [('a', 'x'), ('b', 'y'), ('c', 'z')]

# %%
kv.remove_all(ns)

# %%
kv.count(ns)
# Out:
# 0

# %%
store = get_key_value_store()

# %%
store.get_all("TranslationManager:active")
# Out:
# [('01KEJ79FNQS2B87R9CQVFZ9ZSJ',
#   '{"task_id": "01KEJ79FNQS2B87R9CQVFZ9ZSJ", "name": "NONPAGE_DB_01KEJ79FNMWP1900S9XHWQCC4Y", "length": 72, "completed": 72}'),
#  ('01KEJ7CACH0KES01JPGPQ2ZWQT',
#   '{"task_id": "01KEJ7CACH0KES01JPGPQ2ZWQT", "name": "DB_01KEJ7CACE0ZGKQRDYZ767JC6Q", "length": 72, "completed": 72}')]

# %%
store.remove_all("TranslationManager:active")

# %%
store.remove_all("TranslationManager:completed.01KBGAW1V3HEH93ZYM59BRATJK")
