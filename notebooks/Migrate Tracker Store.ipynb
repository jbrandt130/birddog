# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.store import SQLiteKeyValueStore, DynamoDBKeyValueStore
from birddog.tracker import (
    _TRACKER_KV_TABLE,
    _TRACKER_KV_NS_TRACKER,
    _TRACKER_KV_NS_CHANGE_LOG,
    )
# Out:
# 2026-07-13 12:42:23,580 [INFO] Translation is enabled. Using GCP translator
# 2026-07-13 12:42:23,581 [INFO] Using Google Cloud translation API
# 2026-07-13 12:42:23,581 [INFO] GoogleCloudTranslator using REST API

# %%
local_store = SQLiteKeyValueStore(table_name=_TRACKER_KV_TABLE)

# %%
ddb_store = DynamoDBKeyValueStore(table_name=_TRACKER_KV_TABLE)
# Out:
# 2026-07-13 12:42:25,118 [INFO] Found credentials in environment variables.

# %%
namespaces = [ 
    _TRACKER_KV_NS_TRACKER,
    _TRACKER_KV_NS_CHANGE_LOG,
]

# %%
items = {}

# %%
for ns in namespaces:
    print(f"getting items for namespace {ns}...")
    items[ns] = local_store.get_all(ns)
    print(f"...done. got {len(items[ns])} items.")
# Out:
# getting items for namespace pt...
# ...done. got 190045 items.
# getting items for namespace pcl...
# ...done. got 6256 items.

# %%
items[namespaces[0]][0]
# Out:
# ('Архів:LMAVB', '{"timestamp": "2026-02-07T11:26:12Z"}')

# %%
for ns in namespaces:
    print(f"storing items for namespace {ns}...")
    for i, item in enumerate(items[ns]):
        if i % 1000 == 0:
            print(f"{i}/{len(items[ns])}: {item}")
        ddb_store.insert(ns, item[0], item[1])
# Out:
# storing items for namespace pt...
# 0/190045: ('Архів:LMAVB', '{"timestamp": "2026-02-07T11:26:12Z"}')
# 1000/190045: ('Архів:ДІСЗМО', '{"timestamp": "2023-11-19T11:25:44Z"}')
# 2000/190045: ('Архів:ДАІФО/Р-906/2/49', '{"timestamp": "2026-07-10T15:57:30Z"}')
# 3000/190045: ('Архів:ДАВоО/20/1/28', '{"timestamp": "2025-01-12T18:19:55Z"}')
# 4000/190045: ('Архів:ДАВоО/35/5/165а', '{"timestamp": "2025-12-20T22:55:05Z"}')
# 5000/190045: ('Архів:ДАВоО/96/1/513', '{"timestamp": "2025-12-28T18:59:07Z"}')
# 6000/190045: ('Архів:ДАВоО/Р-3247/2/1866', '{"timestamp": "2025-12-20T17:59:50Z"}')
# 7000/190045: ('Архів:ДАВоО/Р-3247/2/988', '{"timestamp": "2025-12-20T18:12:27Z"}')
# 8000/190045: ('Архів:ДАВіО/234/1', '{"timestamp": "2026-01-12T21:02:17Z"}')
# 9000/190045: ('Архів:ДАВіО/533/1', '{"timestamp": "2025-09-08T19:46:37Z"}')
# 10000/190045: ('Архів:ДАВіО/904/1/136', '{"timestamp": "2023-11-04T23:42:23Z"}')
# 11000/190045: ('Архів:ДАВіО/904/41/39', '{"timestamp": "2026-01-27T22:29:44Z"}')
# 12000/190045: ('Архів:ДАДнО/193/4д', '{"timestamp": "2026-04-06T15:30:24Z"}')
# 13000/190045: ('Архів:ДАДнО/Р-6508/11/70', '{"timestamp": "2025-06-07T13:43:44Z"}')
# 42000/190045: ('Архів:ДАКО/280/2/1473', '{"timestamp": "2025-08-09T16:23:02Z"}')
# 43000/190045: ('Архів:ДАКО/280/2/920', '{"timestamp": "2025-08-09T16:12:09Z"}')
# 44000/190045: ('Архів:ДАКО/384/10/140', '{"timestamp": "2021-03-13T00:06:37Z"}')
# 45000/190045: ('Архів:ДАКО/384/14/48', '{"timestamp": "2025-06-01T17:31:09Z"}')
# 46000/190045: ('Архів:ДАКО/384/5/377', '{"timestamp": "2021-12-13T19:51:06Z"}')
# 47000/190045: ('Архів:ДАКО/384/9/469', '{"timestamp": "2024-08-17T09:46:49Z"}')
# 48000/190045: ('Архів:ДАКО/445/1/282', '{"timestamp": "2026-05-03T21:36:28Z"}')
# 49000/190045: ('Архів:ДАКО/847', '{"timestamp": "2023-03-30T20:47:05Z"}')
# 50000/190045: ('Архів:ДАКО/Р-3050/1/698', '{"timestamp": "2023-08-21T06:38:33Z"}')
# 51000/190045: ('Архів:ДАКО/Р-3066/1/377', '{"timestamp": "2024-11-22T08:59:40Z"}')
# 52000/190045: ('Архів:ДАКО/Р-5634/1/1192', '{"timestamp": "2022-06-16T13:20:46Z"}')
# 53000/190045: ('Архів:ДАКО/Р-5634/1/2093', '{"timestamp": "2023-06-26T21:50:21Z"}')
# 54000/190045: ('Архів:ДАКО/Р-5634/1/2996', '{"timestamp": "2023-07-27T19:10:01Z"}')
# 55000/190045: ('Архів:ДАКО/Р-5634/1/3896', '{"timestamp": "2025-01-31T16:02:22Z"}')
# 56000/190045: ('Архів:ДАКО/Р-5634/1/480', '{"timestamp": "2022-02-13T15:05:13Z"}')
# 57000/190045: ('Архів:ДАКрО/159', '{"timestamp": "2021-02-13T23:16:56Z"}')
# 58000/190045: ('Архів:ДАКрО/219/1/26', '{"timestamp": "2025-03-11T11:35:55Z"}')
# 59000/190045: ('Архів:ДАКрО/239/1', '{"timestamp": "2025-04-05T19:14:08Z"}')
# 60000/190045: ('Архів:ДАКрО/643', '{"timestamp": "2021-02-13T23:30:05Z"}')
# 61000/190045: ('Архів:ДАКрО/П-5907/37', '{"timestamp": "2024-06-07T20:09:58Z"}')
# 62000/190045: ('Архів:ДАКрО/Р-293/1/1874', '{"timestamp": "2026-03-28T14:43:52Z"}')
# 63000/190045: ('Архів:ДАКрО/Р-293/1/561', '{"timestamp": "2026-03-28T15:12:31Z"}')
# 64000/190045: ('Архів:ДАКрО/Р-7915/1/1076', '{"timestamp": "2025-02-22T17:00:44Z"}')
# 65000/190045: ('Архів:ДАКрО/Р-7915/1/537', '{"timestamp": "2025-02-13T19:38:19Z"}')
# 66000/190045: ('Архів:ДАКрО/Р-7915/2/1407', '{"timestamp": "2025-03-05T19:53:38Z"}')
# 67000/190045: ('Архів:ДАКрО/Р-7915/2/2306', '{"timestamp": "2025-04-11T18:28:06Z"}')
# 68000/190045: ('Архів:ДАКрО/Р-7915/2/873', '{"timestamp": "2025-03-05T20:57:22Z"}')
# 69000/190045: ('Архів:ДАЛО/Р-3321/32/13', '{"timestamp": "2026-07-13T10:36:30Z", "user": "Smaxims", "action": "new"}')
# 185000/190045: ('Архів:ЦДАВО/4109/1', '{"timestamp": "2024-11-08T12:36:05Z"}')
# 186000/190045: ('Архів:ЦДАВО/4587/1', '{"timestamp": "2024-11-08T12:50:49Z"}')
# 187000/190045: ('Архів:ЦДАВО/4924/25', '{"timestamp": "2021-02-13T15:03:31Z"}')
# 188000/190045: ('Архів:ЦДАВО/5221/2', '{"timestamp": "2021-02-13T15:25:21Z"}')
# 189000/190045: ('Архів:ЦДАВО/571/1/628', '{"timestamp": "2024-12-20T10:20:20Z"}')
# 190000/190045: ('Архів:ЦДАВО/996', '{"timestamp": "2021-02-13T15:47:31Z"}')
# storing items for namespace pcl...
# 0/6256: ('Архів:Єврейське_містечко/Київська_губернія', '{"timestamp": "2026-07-04T21:04:41Z", "user": "Smaxims", "action": "edit"}')
# 1000/6256: ('Архів:ДАДнО/Р-6508/29/102', '{"timestamp": "2026-07-04T12:32:56Z", "user": "Smaxims", "action": "new"}')
# 2000/6256: ('Архів:ДАЛО/Р-3321/1', '{"timestamp": "2026-07-12T19:12:04Z", "user": "Smaxims", "action": "edit"}')
# 3000/6256: ('Архів:ДАЛО/Р-3321/4/9', '{"timestamp": "2026-07-12T23:38:45Z", "user": "Smaxims", "action": "new"}')
# 4000/6256: ('Архів:ДАХеО/Р-199', '{"timestamp": "2026-06-19T14:02:14Z", "user": "Elsa dom", "action": "edit"}')
# 5000/6256: ('Архів:ДАЧгО/Р-9001/1/194', '{"timestamp": "2026-07-02T05:38:46Z", "user": "Smaxims", "action": "new"}')
# 6000/6256: ('Архів:ДАЧкО/Р-81/1/300', '{"timestamp": "2026-07-03T16:52:55Z", "user": "Smaxims", "action": "new"}')

# %%
import json

# %%
with open("var/DAKRE-R.json") as file:
    obj = json.loads(file.read())

# %%
obj
# Out:
# {'version': 'v2',
#  'archive': 'DAKRE',
#  'subarchive': 'R',
#  'cutoff_date': '2025,01,01',
#  'resolved': {},
#  'unresolved': {},
#  'last_checked_date': '2025,01,01'}

# %%
from birddog.utility import to_utc_format

# %%
to_utc_format("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 to_utc_format("")
#
# File ~/code/birddog/birddog/utility.py:144, in to_utc_format(time_str)
#     142 # Join into full timestamp string
#     143 full_str = ','.join(full_parts)
# --> 144 dt = datetime.strptime(full_str, '%Y,%m,%d,%H:%M')
#     145 return dt.strftime('%Y-%m-%dT%H:%M:%SZ')
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/_strptime.py:653, in _strptime_datetime(cls, data_string, format)
#     650 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     651     """Return a class cls instance based on the input string and the
#     652     format string."""
# --> 653     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     654     tzname, gmtoff = tt[-2:]
#     655     args = tt[:6] + (fraction,)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/_strptime.py:432, in _strptime(data_string, format)
#     430 found = format_regex.match(data_string)
#     431 if not found:
# --> 432     raise ValueError("time data %r does not match format %r" %
#     433                      (data_string, format))
#     434 if len(data_string) != found.end():
#     435     raise ValueError("unconverted data remains: %s" %
#     436                       data_string[found.end():])
#
# ValueError: time data ',01,01,00:00' does not match format '%Y,%m,%d,%H:%M'
