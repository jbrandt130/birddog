# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import (
    PageTracker,
    )
# Out:
# 2025-09-25 15:11:12,268 [INFO] Translation is enabled. Using GCP translator
# 2025-09-25 15:11:12,269 [INFO] Using Google Cloud translation API
# 2025-09-25 15:11:12,269 [INFO] GoogleCloudTranslator using REST API

# %%
tracker = PageTracker()

# %%
updates = tracker.get_updates(prefix="ДАХеО/Д")
# Out:
# 2025-09-25 15:12:12,238 [INFO] PageTracker: refreshing update cache for Архів:ДАХеО/Д

# %%
len(updates)
# Out:
# 1673

# %%
u= [(k,v) for k,v in updates.items()]
u.sort(key=lambda x: x[1])
u.reverse()

# %%
u[:50]
# Out:
# [('Архів:ДАХеО/259/20/20', '2025,08,19,09:22'),
#  ('Архів:ДАХеО/259/20/29', '2025,08,19,09:21'),
#  ('Архів:ДАХеО/259/20/27', '2025,08,19,09:21'),
#  ('Архів:ДАХеО/141', '2025,08,19,09:20'),
#  ('Архів:ДАХеО/141/1', '2025,08,19,09:19'),
#  ('Архів:ДАХеО/141/1/14', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/15', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/16', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/17', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/18', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/19', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/20', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/22', '2025,08,19,09:18'),
#  ('Архів:ДАХеО/141/1/1', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/2', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/3', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/4', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/5', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/6', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/7', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/8', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/9', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/10', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/11', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/12', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/13', '2025,08,19,09:17'),
#  ('Архів:ДАХеО/141/1/21', '2025,08,19,09:07'),
#  ('Архів:ДАХеО/259/1/1', '2025,08,19,09:04'),
#  ('Архів:ДАХеО/259/2', '2025,08,19,09:03'),
#  ('Архів:ДАХеО/259/2/5', '2025,08,19,09:00'),
#  ('Архів:ДАХеО/259/20/8', '2025,08,19,08:56'),
#  ('Архів:ДАХеО/254', '2025,08,19,07:23'),
#  ('Архів:ДАХеО/Р-4033', '2025,07,08,09:51'),
#  ('Архів:ДАХеО/Р', '2025,07,02,10:50'),
#  ('Архів:ДАХеО/22/1/46', '2025,06,11,18:02'),
#  ('Архів:ДАХеО/259', '2025,04,24,06:31'),
#  ('Архів:ДАХеО/259/53/1', '2025,04,04,15:18'),
#  ('Архів:ДАХеО/14/5', '2025,03,25,14:17'),
#  ('Архів:ДАХеО/259/63/2', '2025,02,13,13:25'),
#  ('Архів:ДАХеО/Д', '2024,12,25,15:49'),
#  ('Архів:ДАХеО/328', '2024,12,18,17:57'),
#  ('Архів:ДАХеО/22/1/63', '2024,11,17,00:22'),
#  ('Архів:ДАХеО/22/1', '2024,11,16,22:36'),
#  ('Архів:ДАХеО/22/2', '2024,11,16,20:56'),
#  ('Архів:ДАХеО/22', '2024,11,16,20:51'),
#  ('Архів:ДАХеО/259/20/14', '2024,10,04,07:17'),
#  ('Архів:ДАХеО/259/20/15', '2024,10,04,07:15'),
#  ('Архів:ДАХеО/259/20/22', '2024,10,03,20:27'),
#  ('Архів:ДАХеО/259/20/1', '2024,10,03,18:18'),
#  ('Архів:ДАХеО/259/20/3', '2024,10,03,18:18')]
