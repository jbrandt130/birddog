# %%
import os
from pathlib import Path
# Change cwd to the project root (parent of 'notebooks/')
os.chdir(Path.cwd().parent)
Path.cwd()
# Out:
# PosixPath('/Users/jbrandt/code/birddog')

# %%
from birddog.wiki import lookup_namespace_id, get_recent_changes
# Out:
# 2026-01-11 11:27:47,524 [INFO] Translation is enabled. Using GCP translator
# 2026-01-11 11:27:47,525 [INFO] Using Google Cloud translation API
# 2026-01-11 11:27:47,526 [INFO] GoogleCloudTranslator using REST API

# %%
lookup_namespace_id("Архів")
# Out:
# 2026-01-11 11:27:48,038 [INFO] fetch_url: 1 requests in last 60s → 0.02 req/s
# 116

# %%
commons = "https://commons.wikimedia.org"

# %%
file_namespace_id=lookup_namespace_id("File", base=commons)
file_namespace_id
# Out:
# 2026-01-11 11:28:42,927 [INFO] fetch_url: 3 requests in last 60s → 0.05 req/s
# 6

# %%
lookup_namespace_id("Файл")
# Out:
# 2026-01-11 11:28:55,464 [INFO] fetch_url: 2 requests in last 60s → 0.03 req/s
# 6

# %%
changes = get_recent_changes(namespace=file_namespace_id, base=commons,cutoff_date="2026,01,11")
# Out:
# 2026-01-11 11:32:19,432 [INFO] fetch_url: 123 requests in last 60s → 2.05 req/s
# 2026-01-11 11:32:29,751 [INFO] fetch_url: 126 requests in last 60s → 2.10 req/s
# 2026-01-11 11:32:40,117 [INFO] fetch_url: 127 requests in last 60s → 2.12 req/s
# 2026-01-11 11:32:50,301 [INFO] fetch_url: 128 requests in last 60s → 2.13 req/s
# 2026-01-11 11:33:00,569 [INFO] fetch_url: 129 requests in last 60s → 2.15 req/s
# 2026-01-11 11:33:10,849 [INFO] fetch_url: 130 requests in last 60s → 2.17 req/s
# 2026-01-11 11:33:21,046 [INFO] fetch_url: 149 requests in last 60s → 2.48 req/s
# 2026-01-11 11:33:31,403 [INFO] fetch_url: 147 requests in last 60s → 2.45 req/s
# 2026-01-11 11:33:41,654 [INFO] fetch_url: 147 requests in last 60s → 2.45 req/s
# 2026-01-11 11:33:52,021 [INFO] fetch_url: 146 requests in last 60s → 2.43 req/s
# 2026-01-11 11:34:02,042 [INFO] fetch_url: 146 requests in last 60s → 2.43 req/s
# 2026-01-11 11:34:12,399 [INFO] fetch_url: 146 requests in last 60s → 2.43 req/s
# ...

# %%
len(changes)
# Out:
# 304587

# %%
list(changes.items())[:10]
# Out:
# [('File:ISS018-E-36847 - View of Mexico.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'SchlurcherBot'}),
#  ('File:20252471420 GOES18-ABI-FL-Sandwich-EP122025-2000x2000.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'SchlurcherBot'}),
#  ('File:Ummanz NLP Vorpommersche Boddenlandschaft seen from ferry 2023-06-11 10.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'AmeisenBot'}),
#  ('File:Трипільська культура 5.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'Andreas Kettelhoit (WMSE)'}),
#  ('File:Microspot DC-300 - LCD Panel LCM-5327-24NTK - board-7347.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'Raymond'}),
#  ('File:Sciacca La caduta dellacqua (termale) 1.jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'Rkieferbot'}),
#  ('File:Overlay indexes for degree square 23N098E - DPLA - 292d7050c310f772f4627acb40869b31 (page 127).jpg',
#   {'timestamp': '2026,01,11,18:32', 'user': 'SchlurcherBot'}),
#  ('File:Dop20rgb 32 408 5842 2 ni 2014-05-18.tif',
# ...
